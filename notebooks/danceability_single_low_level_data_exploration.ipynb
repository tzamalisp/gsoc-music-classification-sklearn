# %%
import glob, os
import pathlib
import json
import yaml

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import collections
from pprint import pprint

# %matplotlib inline

# %%
# avoid the module's method call deprecation
try:
    collectionsAbc = collections.abc
except AttributeError:
    collectionsAbc = collections

# %% [markdown]
# Configuring Juputer's options to present more things to the output.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Functions to use

# %% [markdown]
# ## Function to fully flatten each json file

# %%
def flatten_dict_full(d, sep="_"):
    obj = collections.OrderedDict()

    def recurse(t, parent_key=""):
        
        if isinstance(t, list):
            for i in range(len(t)):
                recurse(t[i], parent_key + sep + str(i) if parent_key else str(i))
        elif isinstance(t,dict):
            for k, v in t.items():
                recurse(v, parent_key + sep + k if parent_key else k)
        else:
            obj[parent_key] = t
    recurse(d)

    return obj

# %% [markdown]
# # Load Data GroundTruth

# %% [markdown]
# ## Path declaration

# %%
path_obj = pathlib.Path().absolute()

# %%
path_app = path_obj.as_posix()
# print('Current path:', path_app)
print('Type:', type(path_app))
# Out:
# Type: <class 'str'>

# %%
path_app = os.path.join(os.path.abspath(os.getcwd()), os.pardir)
# path = os.path.join(path, 'danceability', 'features', 'mp3')
# print('Current path:', path_app)
print('Type:', type(path_app))
# Out:
# Type: <class 'str'>

# %% [markdown]
# ## Count all the JSON data included in files

# %%
counter = 0
for root, dirs, files in os.walk(path_app):
    for file in files:
        if(file.endswith(".json")):
#             print(os.path.join(root,file))
            counter += 1
            
print('counted json files:', counter)
# Out:
# counted json files: 10461

# %% [markdown]
# ## Load the GroundTruth file

# %%
with open(os.path.join(path_app, 'acousticbrainz-datasets/danceability/metadata/groundtruth.yaml'), 'r') as stream:
    try:
        groundTr_data = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# %%
# pprint(groundTr_data)

# %%
# pprint(groundTr_data['groundTruth'])

# %%
len(groundTr_data['groundTruth'].keys())
# Out:
# 225

# %% [markdown]
# ## Check the unique folders with tracks and sort them alphabetically

# %%
labeled_tracks = groundTr_data['groundTruth']

# %% [markdown]
# ### Split the keys in Folder - Track Name

# %%
folders = []
for key in labeled_tracks:
    key = key.split('/')
    folders.append(key[0])

# %%
print(folders[:15])
# Out:
# ['Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Blues', 'Blues', 'Blues', 'Blues', 'Blues', 'Blues']

# %% [markdown]
# ### Check the folders

# %%
folders = set(folders)
folders = list(folders)
folders.sort()
folders
# Out:
# ['Alternative',
#  'Blues',
#  'Classical',
#  'Country',
#  'Dance and House',
#  'Folk and New Age',
#  'Hip-Hop and Rap',
#  'House & Garage and Grime',
#  'Jazz',
#  'Jungle and D&B',
#  'Latin',
#  'Pop',
#  'R&B and Soul',
#  'Reggae',
#  'Rock and Metal',
#  'Techno and Electro',
#  'Vocal and Acapella']

# %% [markdown]
# ## Class Name retrieved from GT file

# %%
class_name = groundTr_data['className']

# %%
class_name
# Out:
# 'danceability'

# %% [markdown]
# ## Load a DF containing the tracks from the features path and the info retrieved from the GT file

# %%
path_features = os.path.join(path_app, 'acousticbrainz-datasets/danceability', 'features', 'mp3')

# %%
# path_features

# %%
tracks = []
for key, value in labeled_tracks.items():
    track_dict = {}
    key = key.split('/')
    path_tracks = os.path.join(path_features, key[0])
    for f_name in os.listdir(path_tracks):
        if f_name.startswith(key[1]):
            track_dict['genre_category'] = key[0]
            track_dict['track'] = key[1]
            track_dict['track_path'] = os.path.join(path_features, key[0], f_name)
            track_dict['danceability'] = value
    tracks.append(track_dict)

# %%
# pprint(tracks)

# %%
len(tracks)
# Out:
# 225

# %% [markdown]
# DF that includes the tracks

# %%
df_tracks = pd.DataFrame(data=tracks)

# %% [markdown]
# Plot the track's paths

# %%
df_tracks.head()
# Out:
#   genre_category                                          track  \
# 0    Alternative         02 Happy Birthday - Altered Images.mp3
# 1    Alternative                03 How Soon Is Now - Smiths.mp3
# 2    Alternative  04 Pearly Dewdrops' Drops - Cocteau Twins.mp3
# 3    Alternative                 06 Mr Brightside - Killers.mp3
# 4    Alternative                           06 Song 2 - Blur.mp3
#
#                                                                                                                                                                                   track_path  \
# 0         /home/iotlab_user/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/02 Happy Birthday - Altered Images.mp3.json
# 1                /home/iotlab_user/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/03 How Soon Is Now - Smiths.mp3.json
# 2  /home/iotlab_user/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/04 Pearly Dewdrops' Drops - Cocteau Twins.mp3.json
# 3                 /home/iotlab_user/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/06 Mr Brightside - Killers.mp3.json
# 4                           /home/iotlab_user/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/06 Song 2 - Blur.mp3.json
#
#     danceability
# 0      danceable
# 1  not_danceable
# 2  not_danceable
# 3      danceable
# 4      danceable

# %% [markdown]
# Check the className distribution of the data based on the 'genre_category'

# %%
df_tracks.hist('genre_category', class_name, figsize=(15,6), edgecolor="k")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff89382df10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff8917727d0>],
#       dtype=object)

# %% [markdown]
# Data distribution based on the genres

# %%
df_tracks['genre_category'].value_counts()
# Out:
# Jungle and D&B              22
# Latin                       22
# Dance and House             21
# Hip-Hop and Rap             19
# Vocal and Acapella          17
# Folk and New Age            16
# Techno and Electro          16
# Rock and Metal              13
# R&B and Soul                13
# Reggae                      12
# House & Garage and Grime    10
# Alternative                  9
# Blues                        8
# Country                      8
# Pop                          7
# Classical                    6
# Jazz                         6
# Name: genre_category, dtype: int64

# %% [markdown]
# # Load a Single JSON low-level file and explore its data

# %%
with open(df_tracks['track_path'].iloc[0]) as json_file:
    data_feats = json.load(json_file)

# %%
# pprint(data_feats)

# %%
data_feats.keys()
# Out:
# dict_keys(['lowlevel', 'metadata', 'rhythm', 'tonal'])

# %% [markdown]
# ## metadata key's parts

# %%
data_feats['metadata']
# Out:
# {'audio_properties': {'analysis_sample_rate': 44100,
#   'bit_rate': 128000,
#   'equal_loudness': 0,
#   'length': 178.259597778,
#   'lossless': 0,
#   'replay_gain': -15.0935020447,
#   'sample_rate': 44100,
#   'codec': 'mp3',
#   'downmix': 'mix',
#   'md5_encoded': '9a09eb0c8b468e32c61ab36080f0f5f0'},
#  'tags': {'file_name': '02 Happy Birthday - Altered Images.mp3',
#   'album': ['John Peel - A Tribute [UK] Disc 2'],
#   'albumartist': ['Various Artists'],
#   'artist': ['Various Artists'],
#   'date': ['2005'],
#   'genre': ['Rock/Pop'],
#   'label': ['WSM'],
#   'length': ['178320'],
#   'title': ['Happy Birthday - Altered Images'],
#   'tracknumber': ['2']},
#  'version': {'essentia': '2.1-beta2',
#   'essentia_git_sha': 'v2.1_beta2',
#   'extractor': 'music 1.0'}}

# %%
data_feats['metadata'].keys()
# Out:
# dict_keys(['audio_properties', 'tags', 'version'])

# %% [markdown]
# ## tonal
#
# Based on the Gaia's classification configuration file (yaml), these are the features that will be enumerated.
# - Enumeration in: 'tonal.chords_key', 'tonal.chords_scale', 'tonal.key_key', 'tonal.key_scale'

# %%
# data_feats['tonal']

# %%
enum_keys = ['chords_key', 'chords_scale', 'key_key', 'key_scale']
for item in enum_keys:
    if item in list(data_feats['tonal'].keys()):
        print('{}: {}'.format(item, data_feats['tonal'][item]))
# Out:
# chords_key: A
# chords_scale: major
# key_key: D
# key_scale: minor

# %%
data_feats['tonal'].keys()
# Out:
# dict_keys(['chords_changes_rate', 'chords_number_rate', 'chords_strength', 'hpcp_entropy', 'key_strength', 'tuning_diatonic_strength', 'tuning_equal_tempered_deviation', 'tuning_frequency', 'tuning_nontempered_energy_ratio', 'hpcp', 'chords_histogram', 'thpcp', 'chords_key', 'chords_scale', 'key_key', 'key_scale'])

# %% [markdown]
# ## low-level

# %%
low_level = data_feats['lowlevel']

# %%
low_level.keys()
# Out:
# dict_keys(['average_loudness', 'barkbands_crest', 'barkbands_flatness_db', 'barkbands_kurtosis', 'barkbands_skewness', 'barkbands_spread', 'dissonance', 'dynamic_complexity', 'erbbands_crest', 'erbbands_flatness_db', 'erbbands_kurtosis', 'erbbands_skewness', 'erbbands_spread', 'hfc', 'melbands_crest', 'melbands_flatness_db', 'melbands_kurtosis', 'melbands_skewness', 'melbands_spread', 'pitch_salience', 'silence_rate_20dB', 'silence_rate_30dB', 'silence_rate_60dB', 'spectral_centroid', 'spectral_complexity', 'spectral_decrease', 'spectral_energy', 'spectral_energyband_high', 'spectral_energyband_low', 'spectral_energyband_middle_high', 'spectral_energyband_middle_low', 'spectral_entropy', 'spectral_flux', 'spectral_kurtosis', 'spectral_rms', 'spectral_rolloff', 'spectral_skewness', 'spectral_spread', 'spectral_strongpeak', 'zerocrossingrate', 'barkbands', 'erbbands', 'gfcc', 'melbands', 'mfcc', 'spectral_contrast_coeffs', 'spectral_contrast_valleys'])

# %% [markdown]
# ## rhythm

# %%
rhythm = data_feats['rhythm']

# %%
rhythm.keys()
# Out:
# dict_keys(['beats_count', 'beats_loudness', 'bpm', 'bpm_histogram_first_peak_bpm', 'bpm_histogram_first_peak_spread', 'bpm_histogram_first_peak_weight', 'bpm_histogram_second_peak_bpm', 'bpm_histogram_second_peak_spread', 'bpm_histogram_second_peak_weight', 'danceability', 'onset_rate', 'beats_loudness_band_ratio', 'beats_position'])

# %%
# pprint(rhythm)

# %% [markdown]
# ## Remove the `metadata` key and the `rhythm.beats_position`

# %%
data_feats.keys()
# Out:
# dict_keys(['lowlevel', 'metadata', 'rhythm', 'tonal'])

# %% [markdown]
# Delete `metadata`

# %%
if 'metadata' in data_feats:
    del data_feats['metadata']

# %%
data_feats.keys()
# Out:
# dict_keys(['lowlevel', 'rhythm', 'tonal'])

# %% [markdown]
# Delete `rhythm.beats_position`

# %%
print(data_feats['rhythm'].keys())
print()
print('length:', len(list(data_feats['rhythm'].keys())))
# Out:
# dict_keys(['beats_count', 'beats_loudness', 'bpm', 'bpm_histogram_first_peak_bpm', 'bpm_histogram_first_peak_spread', 'bpm_histogram_first_peak_weight', 'bpm_histogram_second_peak_bpm', 'bpm_histogram_second_peak_spread', 'bpm_histogram_second_peak_weight', 'danceability', 'onset_rate', 'beats_loudness_band_ratio', 'beats_position'])
#
# length: 13

# %%
if 'beats_position' in data_feats['rhythm']:
    del data_feats['rhythm']['beats_position']

# %%
print(data_feats['rhythm'].keys())
print()
print('length:', len(list(data_feats['rhythm'].keys())))
# Out:
# dict_keys(['beats_count', 'beats_loudness', 'bpm', 'bpm_histogram_first_peak_bpm', 'bpm_histogram_first_peak_spread', 'bpm_histogram_first_peak_weight', 'bpm_histogram_second_peak_bpm', 'bpm_histogram_second_peak_spread', 'bpm_histogram_second_peak_weight', 'danceability', 'onset_rate', 'beats_loudness_band_ratio'])
#
# length: 12

# %% [markdown]
# ## Transform to a single DF

# %%
data_feats = flatten_dict_full(data_feats)

# %%
len(data_feats.keys())
# Out:
# 2651

# %%
df_single_track = pd.DataFrame(data_feats, columns=data_feats.keys(), index=[0])

# %%
df_single_track
# Out:
#    lowlevel_average_loudness  lowlevel_barkbands_crest_dmean  \
# 0                   0.940232                         2.76666
#
#    lowlevel_barkbands_crest_dmean2  lowlevel_barkbands_crest_dvar  \
# 0                         4.448297                       5.745806
#
#    lowlevel_barkbands_crest_dvar2  lowlevel_barkbands_crest_max  \
# 0                       14.987641                     26.722847
#
#    lowlevel_barkbands_crest_mean  lowlevel_barkbands_crest_median  \
# 0                      10.807129                         9.691339
#
#    lowlevel_barkbands_crest_min  lowlevel_barkbands_crest_var  \
# 0                      2.798266                     24.122204
#
#    lowlevel_barkbands_flatness_db_dmean  \
# 0                               0.02372
#
#    lowlevel_barkbands_flatness_db_dmean2  lowlevel_barkbands_flatness_db_dvar  \
# 0                               0.035958                             0.000526
#
#    lowlevel_barkbands_flatness_db_dvar2  lowlevel_barkbands_flatness_db_max  \
# 0                              0.001158                            0.627938
#
#    lowlevel_barkbands_flatness_db_mean  lowlevel_barkbands_flatness_db_median  \
# 0                             0.176747                               0.146083
#
#    lowlevel_barkbands_flatness_db_min  lowlevel_barkbands_flatness_db_var  \
# 0                            0.040839                            0.010974
#
#    lowlevel_barkbands_kurtosis_dmean  lowlevel_barkbands_kurtosis_dmean2  \
# 0                            4.54692                            6.845909
#
#    lowlevel_barkbands_kurtosis_dvar  lowlevel_barkbands_kurtosis_dvar2  \
# 0                        239.760788                         517.971375
#
#    lowlevel_barkbands_kurtosis_max  lowlevel_barkbands_kurtosis_mean  \
# 0                       635.369263                          6.762696
#
#    lowlevel_barkbands_kurtosis_median  lowlevel_barkbands_kurtosis_min  \
# 0                            1.556325                         -1.92447
#
#    lowlevel_barkbands_kurtosis_var  lowlevel_barkbands_skewness_dmean  \
# 0                       522.650879                           0.626882
#
#    lowlevel_barkbands_skewness_dmean2  lowlevel_barkbands_skewness_dvar  \
# 0                            0.939088                            0.5422
#
#    lowlevel_barkbands_skewness_dvar2  lowlevel_barkbands_skewness_max  \
# 0                            1.18476                        18.368624
#
#    lowlevel_barkbands_skewness_mean  lowlevel_barkbands_skewness_median  \
# 0                          1.535155                            1.272417
#
#    lowlevel_barkbands_skewness_min  lowlevel_barkbands_skewness_var  \
# 0                        -3.235665                         2.187619
#
#    lowlevel_barkbands_spread_dmean  lowlevel_barkbands_spread_dmean2  \
# 0                         5.136347                          7.900097
#
#    lowlevel_barkbands_spread_dvar  lowlevel_barkbands_spread_dvar2  \
# 0                       45.053402                       109.031082
#
#    lowlevel_barkbands_spread_max  lowlevel_barkbands_spread_mean  \
# 0                     133.435379                       19.025879
#
#    lowlevel_barkbands_spread_median  lowlevel_barkbands_spread_min  \
# 0                          17.50462                       0.033004
#
#    lowlevel_barkbands_spread_var  lowlevel_dissonance_dmean  \
# 0                     164.326553                   0.024475
#
#    lowlevel_dissonance_dmean2  lowlevel_dissonance_dvar  \
# 0                    0.040256                  0.000793
#
#    lowlevel_dissonance_dvar2  lowlevel_dissonance_max  \
# 0                   0.002014                 0.499982
#
#    lowlevel_dissonance_mean  lowlevel_dissonance_median  \
# 0                  0.437224                    0.460024
#
#    lowlevel_dissonance_min  lowlevel_dissonance_var  \
# 0                 0.074953                 0.005112
#
#    lowlevel_dynamic_complexity  lowlevel_erbbands_crest_dmean  \
# 0                     3.144951                       3.044979
#
#    lowlevel_erbbands_crest_dmean2  lowlevel_erbbands_crest_dvar  \
# 0                        4.833197                      8.159853
#
#    lowlevel_erbbands_crest_dvar2  lowlevel_erbbands_crest_max  \
# 0                      19.592464                    32.387486
#
#    lowlevel_erbbands_crest_mean  lowlevel_erbbands_crest_median  \
# 0                     10.746548                        9.160177
#
#    lowlevel_erbbands_crest_min  lowlevel_erbbands_crest_var  \
# 0                     2.319327                    35.120968
#
#    lowlevel_erbbands_flatness_db_dmean  lowlevel_erbbands_flatness_db_dmean2  \
# 0                             0.021678                              0.028215
#
#    lowlevel_erbbands_flatness_db_dvar  lowlevel_erbbands_flatness_db_dvar2  \
# 0                            0.000464                              0.00076
#
#    lowlevel_erbbands_flatness_db_max  lowlevel_erbbands_flatness_db_mean  \
# 0                           0.590239                            0.200973
#
#    lowlevel_erbbands_flatness_db_median  lowlevel_erbbands_flatness_db_min  \
# 0                              0.182578                           0.061867
#
#    lowlevel_erbbands_flatness_db_var  lowlevel_erbbands_kurtosis_dmean  \
# 0                           0.008523                          1.728126
#
#    lowlevel_erbbands_kurtosis_dmean2  lowlevel_erbbands_kurtosis_dvar  \
# 0                           2.560681                        20.840925
#
#    lowlevel_erbbands_kurtosis_dvar2  lowlevel_erbbands_kurtosis_max  \
# 0                         42.721596                      135.502365
#
#    lowlevel_erbbands_kurtosis_mean  lowlevel_erbbands_kurtosis_median  \
# 0                         2.085207                          -0.119843
#
#    lowlevel_erbbands_kurtosis_min  lowlevel_erbbands_kurtosis_var  \
# 0                       -1.893416                       64.254738
#
#    lowlevel_erbbands_skewness_dmean  lowlevel_erbbands_skewness_dmean2  \
# 0                          0.426052                           0.635312
#
#    lowlevel_erbbands_skewness_dvar  lowlevel_erbbands_skewness_dvar2  \
# 0                         0.203251                          0.415034
#
#    lowlevel_erbbands_skewness_max  lowlevel_erbbands_skewness_mean  \
# 0                        8.913706                         0.557501
#
#    lowlevel_erbbands_skewness_median  lowlevel_erbbands_skewness_min  \
# 0                           0.355854                       -3.117027
#
#    lowlevel_erbbands_skewness_var  lowlevel_erbbands_spread_dmean  \
# 0                         1.22907                        7.854256
#
#    lowlevel_erbbands_spread_dmean2  lowlevel_erbbands_spread_dvar  \
# 0                        11.634526                       80.05661
#
#    lowlevel_erbbands_spread_dvar2  lowlevel_erbbands_spread_max  \
# 0                      170.342407                    140.270981
#
#    lowlevel_erbbands_spread_mean  lowlevel_erbbands_spread_median  \
# 0                      33.961555                        31.566576
#
#    lowlevel_erbbands_spread_min  lowlevel_erbbands_spread_var  \
# 0                      0.390867                    396.588562
#
#    lowlevel_hfc_dmean  lowlevel_hfc_dmean2  lowlevel_hfc_dvar  \
# 0            6.294073              8.93891         105.744316
#
#    lowlevel_hfc_dvar2  lowlevel_hfc_max  lowlevel_hfc_mean  \
# 0          211.105164        302.891663           21.91123
#
#    lowlevel_hfc_median  lowlevel_hfc_min  lowlevel_hfc_var  \
# 0            17.740328      1.049553e-16        418.785492
#
#    lowlevel_melbands_crest_dmean  lowlevel_melbands_crest_dmean2  \
# 0                       3.652648                        5.981247
#
#    lowlevel_melbands_crest_dvar  lowlevel_melbands_crest_dvar2  \
# 0                      10.04481                      26.792372
#
#    lowlevel_melbands_crest_max  lowlevel_melbands_crest_mean  \
# 0                     34.42762                     14.934194
#
#    lowlevel_melbands_crest_median  lowlevel_melbands_crest_min  \
# 0                       13.797116                     1.004465
#
#    lowlevel_melbands_crest_var  lowlevel_melbands_flatness_db_dmean  \
# 0                    36.047642                             0.027733
#
#    lowlevel_melbands_flatness_db_dmean2  lowlevel_melbands_flatness_db_dvar  \
# 0                              0.042425                            0.000765
#
#    lowlevel_melbands_flatness_db_dvar2  lowlevel_melbands_flatness_db_max  \
# 0                             0.001806                           0.709166
#
#    lowlevel_melbands_flatness_db_mean  lowlevel_melbands_flatness_db_median  \
# 0                            0.219119                              0.186654
#
#    lowlevel_melbands_flatness_db_min  lowlevel_melbands_flatness_db_var  \
# 0                       1.725733e-07                           0.013507
#
#    lowlevel_melbands_kurtosis_dmean  lowlevel_melbands_kurtosis_dmean2  \
# 0                          6.596013                          10.333323
#
#    lowlevel_melbands_kurtosis_dvar  lowlevel_melbands_kurtosis_dvar2  \
# 0                       115.083527                         276.52533
#
#    lowlevel_melbands_kurtosis_max  lowlevel_melbands_kurtosis_mean  \
# 0                      200.180054                        10.981357
#
#    lowlevel_melbands_kurtosis_median  lowlevel_melbands_kurtosis_min  \
# 0                           5.714105                        -1.85252
#
#    lowlevel_melbands_kurtosis_var  lowlevel_melbands_skewness_dmean  \
# 0                      237.040222                          0.757478
#
#    lowlevel_melbands_skewness_dmean2  lowlevel_melbands_skewness_dvar  \
# 0                           1.159081                         0.636685
#
#    lowlevel_melbands_skewness_dvar2  lowlevel_melbands_skewness_max  \
# 0                          1.471497                       10.444663
#
#    lowlevel_melbands_skewness_mean  lowlevel_melbands_skewness_median  \
# 0                         2.237297                           2.010942
#
#    lowlevel_melbands_skewness_min  lowlevel_melbands_skewness_var  \
# 0                         -2.4072                         2.18306
#
#    lowlevel_melbands_spread_dmean  lowlevel_melbands_spread_dmean2  \
# 0                        7.272582                        11.284691
#
#    lowlevel_melbands_spread_dvar  lowlevel_melbands_spread_dvar2  \
# 0                     118.792328                        276.6091
#
#    lowlevel_melbands_spread_max  lowlevel_melbands_spread_mean  \
# 0                    248.903458                      22.854174
#
#    lowlevel_melbands_spread_median  lowlevel_melbands_spread_min  \
# 0                         20.11404                      0.175563
#
#    lowlevel_melbands_spread_var  lowlevel_pitch_salience_dmean  \
# 0                    378.054749                        0.07604
#
#    lowlevel_pitch_salience_dmean2  lowlevel_pitch_salience_dvar  \
# 0                        0.124146                      0.004478
#
#    lowlevel_pitch_salience_dvar2  lowlevel_pitch_salience_max  \
# 0                        0.01217                      0.99583
#
#    lowlevel_pitch_salience_mean  lowlevel_pitch_salience_median  \
# 0                      0.548196                        0.559924
#
#    lowlevel_pitch_salience_min  lowlevel_pitch_salience_var  \
# 0                     0.033791                     0.012876
#
#    lowlevel_silence_rate_20dB_dmean  lowlevel_silence_rate_20dB_dmean2  \
# 0                                 0                                  0
#
#    lowlevel_silence_rate_20dB_dvar  lowlevel_silence_rate_20dB_dvar2  \
# 0                                0                                 0
#
#    lowlevel_silence_rate_20dB_max  lowlevel_silence_rate_20dB_mean  \
# 0                               1                                1
#
#    lowlevel_silence_rate_20dB_median  lowlevel_silence_rate_20dB_min  \
# 0                                  1                               1
#
#    lowlevel_silence_rate_20dB_var  lowlevel_silence_rate_30dB_dmean  \
# 0                               0                                 0
#
#    lowlevel_silence_rate_30dB_dmean2  lowlevel_silence_rate_30dB_dvar  \
# 0                                  0                                0
#
#    lowlevel_silence_rate_30dB_dvar2  lowlevel_silence_rate_30dB_max  \
# 0                                 0                               1
#
#    lowlevel_silence_rate_30dB_mean  lowlevel_silence_rate_30dB_median  \
# 0                                1                                  1
#
#    lowlevel_silence_rate_30dB_min  lowlevel_silence_rate_30dB_var  \
# 0                               1                               0
#
#    lowlevel_silence_rate_60dB_dmean  lowlevel_silence_rate_60dB_dmean2  \
# 0                           0.02032                           0.040646
#
#    lowlevel_silence_rate_60dB_dvar  lowlevel_silence_rate_60dB_dvar2  \
# 0                         0.019907                          0.040554
#
#    lowlevel_silence_rate_60dB_max  lowlevel_silence_rate_60dB_mean  \
# 0                               1                         0.087002
#
#    lowlevel_silence_rate_60dB_median  lowlevel_silence_rate_60dB_min  \
# 0                                  0                               0
#
#    lowlevel_silence_rate_60dB_var  lowlevel_spectral_centroid_dmean  \
# 0                        0.079431                        247.013489
#
#    lowlevel_spectral_centroid_dmean2  lowlevel_spectral_centroid_dvar  \
# 0                         379.758209                     94818.039062
#
#    lowlevel_spectral_centroid_dvar2  lowlevel_spectral_centroid_max  \
# 0                     220693.765625                    11838.609375
#
#    lowlevel_spectral_centroid_mean  lowlevel_spectral_centroid_median  \
# 0                      1261.011719                        1185.409668
#
#    lowlevel_spectral_centroid_min  lowlevel_spectral_centroid_var  \
# 0                      223.340637                      596974.125
#
#    lowlevel_spectral_complexity_dmean  lowlevel_spectral_complexity_dmean2  \
# 0                             3.48261                             5.167014
#
#    lowlevel_spectral_complexity_dvar  lowlevel_spectral_complexity_dvar2  \
# 0                          15.210599                           29.246887
#
#    lowlevel_spectral_complexity_max  lowlevel_spectral_complexity_mean  \
# 0                                61                          18.320787
#
#    lowlevel_spectral_complexity_median  lowlevel_spectral_complexity_min  \
# 0                                   19                                 0
#
#    lowlevel_spectral_complexity_var  lowlevel_spectral_decrease_dmean  \
# 0                        101.436401                      2.262940e-09
#
#    lowlevel_spectral_decrease_dmean2  lowlevel_spectral_decrease_dvar  \
# 0                       3.413201e-09                     9.360516e-18
#
#    lowlevel_spectral_decrease_dvar2  lowlevel_spectral_decrease_max  \
# 0                      2.211047e-17                    1.347426e-28
#
#    lowlevel_spectral_decrease_mean  lowlevel_spectral_decrease_median  \
# 0                    -6.141155e-09                      -5.379616e-09
#
#    lowlevel_spectral_decrease_min  lowlevel_spectral_decrease_var  \
# 0                   -2.997968e-08                    2.083257e-17
#
#    lowlevel_spectral_energy_dmean  lowlevel_spectral_energy_dmean2  \
# 0                        0.008904                          0.01333
#
#    lowlevel_spectral_energy_dvar  lowlevel_spectral_energy_dvar2  \
# 0                       0.000139                        0.000323
#
#    lowlevel_spectral_energy_max  lowlevel_spectral_energy_mean  \
# 0                      0.116706                       0.025166
#
#    lowlevel_spectral_energy_median  lowlevel_spectral_energy_min  \
# 0                         0.022219                  9.933807e-21
#
#    lowlevel_spectral_energy_var  lowlevel_spectral_energyband_high_dmean  \
# 0                      0.000335                                  0.00043
#
#    lowlevel_spectral_energyband_high_dmean2  \
# 0                                  0.000583
#
#    lowlevel_spectral_energyband_high_dvar  \
# 0                                0.000001
#
#    lowlevel_spectral_energyband_high_dvar2  \
# 0                                 0.000003
#
#    lowlevel_spectral_energyband_high_max  \
# 0                               0.040817
#
#    lowlevel_spectral_energyband_high_mean  \
# 0                                0.000924
#
#    lowlevel_spectral_energyband_high_median  \
# 0                                  0.000307
#
#    lowlevel_spectral_energyband_high_min  \
# 0                           7.174869e-21
#
#    lowlevel_spectral_energyband_high_var  \
# 0                               0.000003
#
#    lowlevel_spectral_energyband_low_dmean  \
# 0                                0.004428
#
#    lowlevel_spectral_energyband_low_dmean2  \
# 0                                   0.0075
#
#    lowlevel_spectral_energyband_low_dvar  \
# 0                               0.000083
#
#    lowlevel_spectral_energyband_low_dvar2  \
# 0                                0.000217
#
#    lowlevel_spectral_energyband_low_max  \
# 0                              0.070612
#
#    lowlevel_spectral_energyband_low_mean  \
# 0                               0.005223
#
#    lowlevel_spectral_energyband_low_median  \
# 0                                 0.001342
#
#    lowlevel_spectral_energyband_low_min  lowlevel_spectral_energyband_low_var  \
# 0                          1.942557e-23                              0.000092
#
#    lowlevel_spectral_energyband_middle_high_dmean  \
# 0                                        0.002381
#
#    lowlevel_spectral_energyband_middle_high_dmean2  \
# 0                                         0.003639
#
#    lowlevel_spectral_energyband_middle_high_dvar  \
# 0                                       0.000012
#
#    lowlevel_spectral_energyband_middle_high_dvar2  \
# 0                                        0.000027
#
#    lowlevel_spectral_energyband_middle_high_max  \
# 0                                      0.055766
#
#    lowlevel_spectral_energyband_middle_high_mean  \
# 0                                       0.006767
#
#    lowlevel_spectral_energyband_middle_high_median  \
# 0                                         0.004348
#
#    lowlevel_spectral_energyband_middle_high_min  \
# 0                                  1.318605e-21
#
#    lowlevel_spectral_energyband_middle_high_var  \
# 0                                      0.000054
#
#    lowlevel_spectral_energyband_middle_low_dmean  \
# 0                                       0.005804
#
#    lowlevel_spectral_energyband_middle_low_dmean2  \
# 0                                        0.009041
#
#    lowlevel_spectral_energyband_middle_low_dvar  \
# 0                                      0.000074
#
#    lowlevel_spectral_energyband_middle_low_dvar2  \
# 0                                        0.00019
#
#    lowlevel_spectral_energyband_middle_low_max  \
# 0                                     0.107318
#
#    lowlevel_spectral_energyband_middle_low_mean  \
# 0                                      0.013227
#
#    lowlevel_spectral_energyband_middle_low_median  \
# 0                                         0.01067
#
#    lowlevel_spectral_energyband_middle_low_min  \
# 0                                 1.887367e-22
#
#    lowlevel_spectral_energyband_middle_low_var  \
# 0                                     0.000121
#
#    lowlevel_spectral_entropy_dmean  lowlevel_spectral_entropy_dmean2  \
# 0                          0.19779                          0.275119
#
#    lowlevel_spectral_entropy_dvar  lowlevel_spectral_entropy_dvar2  \
# 0                        0.052793                         0.100931
#
#    lowlevel_spectral_entropy_max  lowlevel_spectral_entropy_mean  \
# 0                        9.81281                        7.226406
#
#    lowlevel_spectral_entropy_median  lowlevel_spectral_entropy_min  \
# 0                           7.45055                       3.100218
#
#    lowlevel_spectral_entropy_var  lowlevel_spectral_flux_dmean  \
# 0                       0.874166                      0.026862
#
#    lowlevel_spectral_flux_dmean2  lowlevel_spectral_flux_dvar  \
# 0                       0.040187                     0.000885
#
#    lowlevel_spectral_flux_dvar2  lowlevel_spectral_flux_max  \
# 0                      0.001734                    0.302328
#
#    lowlevel_spectral_flux_mean  lowlevel_spectral_flux_median  \
# 0                      0.08659                        0.07892
#
#    lowlevel_spectral_flux_min  lowlevel_spectral_flux_var  \
# 0                6.566880e-11                    0.002928
#
#    lowlevel_spectral_kurtosis_dmean  lowlevel_spectral_kurtosis_dmean2  \
# 0                          4.026096                           6.480063
#
#    lowlevel_spectral_kurtosis_dvar  lowlevel_spectral_kurtosis_dvar2  \
# 0                       109.164337                        297.492584
#
#    lowlevel_spectral_kurtosis_max  lowlevel_spectral_kurtosis_mean  \
# 0                      315.019928                        11.950824
#
#    lowlevel_spectral_kurtosis_median  lowlevel_spectral_kurtosis_min  \
# 0                           4.081501                       -1.440013
#
#    lowlevel_spectral_kurtosis_var  lowlevel_spectral_rms_dmean  \
# 0                      822.924194                     0.000809
#
#    lowlevel_spectral_rms_dmean2  lowlevel_spectral_rms_dvar  \
# 0                      0.001168                7.888653e-07
#
#    lowlevel_spectral_rms_dvar2  lowlevel_spectral_rms_max  \
# 0                     0.000002                    0.01067
#
#    lowlevel_spectral_rms_mean  lowlevel_spectral_rms_median  \
# 0                    0.004577                      0.004656
#
#    lowlevel_spectral_rms_min  lowlevel_spectral_rms_var  \
# 0               3.113120e-12                   0.000004
#
#    lowlevel_spectral_rolloff_dmean  lowlevel_spectral_rolloff_dmean2  \
# 0                       501.416382                        839.424255
#
#    lowlevel_spectral_rolloff_dvar  lowlevel_spectral_rolloff_dvar2  \
# 0                     825722.5625                        1889652.5
#
#    lowlevel_spectral_rolloff_max  lowlevel_spectral_rolloff_mean  \
# 0                   19336.816406                     1509.529541
#
#    lowlevel_spectral_rolloff_median  lowlevel_spectral_rolloff_min  \
# 0                       1184.326172                     107.666016
#
#    lowlevel_spectral_rolloff_var  lowlevel_spectral_skewness_dmean  \
# 0                     2454966.75                          0.331103
#
#    lowlevel_spectral_skewness_dmean2  lowlevel_spectral_skewness_dvar  \
# 0                           0.519606                          0.25466
#
#    lowlevel_spectral_skewness_dvar2  lowlevel_spectral_skewness_max  \
# 0                          0.593803                       14.962457
#
#    lowlevel_spectral_skewness_mean  lowlevel_spectral_skewness_median  \
# 0                         2.031183                           1.506641
#
#    lowlevel_spectral_skewness_min  lowlevel_spectral_skewness_var  \
# 0                       -0.083107                        3.682333
#
#    lowlevel_spectral_spread_dmean  lowlevel_spectral_spread_dmean2  \
# 0                      552523.875                       772800.125
#
#    lowlevel_spectral_spread_dvar  lowlevel_spectral_spread_dvar2  \
# 0                   696362270720                    1.386608e+12
#
#    lowlevel_spectral_spread_max  lowlevel_spectral_spread_mean  \
# 0                      41914944                        4172137
#
#    lowlevel_spectral_spread_median  lowlevel_spectral_spread_min  \
# 0                       3934539.25                  426749.40625
#
#    lowlevel_spectral_spread_var  lowlevel_spectral_strongpeak_dmean  \
# 0                  5.861572e+12                            0.632493
#
#    lowlevel_spectral_strongpeak_dmean2  lowlevel_spectral_strongpeak_dvar  \
# 0                             1.037717                           1.042264
#
#    lowlevel_spectral_strongpeak_dvar2  lowlevel_spectral_strongpeak_max  \
# 0                            2.565678                         19.024202
#
#    lowlevel_spectral_strongpeak_mean  lowlevel_spectral_strongpeak_median  \
# 0                           1.213341                             0.789028
#
#    lowlevel_spectral_strongpeak_min  lowlevel_spectral_strongpeak_var  \
# 0                                 0                          1.753289
#
#    lowlevel_zerocrossingrate_dmean  lowlevel_zerocrossingrate_dmean2  \
# 0                         0.009006                          0.010366
#
#    lowlevel_zerocrossingrate_dvar  lowlevel_zerocrossingrate_dvar2  \
# 0                        0.000172                          0.00018
#
#    lowlevel_zerocrossingrate_max  lowlevel_zerocrossingrate_mean  \
# 0                       0.512695                        0.058509
#
#    lowlevel_zerocrossingrate_median  lowlevel_zerocrossingrate_min  \
# 0                          0.052734                       0.006836
#
#    lowlevel_zerocrossingrate_var  lowlevel_barkbands_dmean_0  \
# 0                       0.001694                    0.000072
#
#    lowlevel_barkbands_dmean_1  lowlevel_barkbands_dmean_2  \
# 0                    0.002661                    0.001789
#
#    lowlevel_barkbands_dmean_3  lowlevel_barkbands_dmean_4  \
# 0                    0.001821                    0.002378
#
#    lowlevel_barkbands_dmean_5  lowlevel_barkbands_dmean_6  \
# 0                     0.00111                    0.001453
#
#    lowlevel_barkbands_dmean_7  lowlevel_barkbands_dmean_8  \
# 0                    0.000819                    0.000793
#
#    lowlevel_barkbands_dmean_9  lowlevel_barkbands_dmean_10  \
# 0                    0.000962                     0.000714
#
#    lowlevel_barkbands_dmean_11  lowlevel_barkbands_dmean_12  \
# 0                     0.000608                     0.000298
#
#    lowlevel_barkbands_dmean_13  lowlevel_barkbands_dmean_14  \
# 0                     0.000445                     0.000292
#
#    lowlevel_barkbands_dmean_15  lowlevel_barkbands_dmean_16  \
# 0                     0.000312                     0.000352
#
#    lowlevel_barkbands_dmean_17  lowlevel_barkbands_dmean_18  \
# 0                     0.000161                     0.000212
#
#    lowlevel_barkbands_dmean_19  lowlevel_barkbands_dmean_20  \
# 0                     0.000146                     0.000149
#
#    lowlevel_barkbands_dmean_21  lowlevel_barkbands_dmean_22  \
# 0                     0.000081                     0.000069
#
#    lowlevel_barkbands_dmean_23  lowlevel_barkbands_dmean_24  \
# 0                     0.000086                     0.000057
#
#    lowlevel_barkbands_dmean_25  lowlevel_barkbands_dmean_26  \
# 0                     0.000015                 1.799633e-07
#
#    lowlevel_barkbands_dmean2_0  lowlevel_barkbands_dmean2_1  \
# 0                     0.000112                     0.004724
#
#    lowlevel_barkbands_dmean2_2  lowlevel_barkbands_dmean2_3  \
# 0                     0.003108                     0.003117
#
#    lowlevel_barkbands_dmean2_4  lowlevel_barkbands_dmean2_5  \
# 0                     0.003938                     0.001707
#
#    lowlevel_barkbands_dmean2_6  lowlevel_barkbands_dmean2_7  \
# 0                     0.002083                     0.001312
#
#    lowlevel_barkbands_dmean2_8  lowlevel_barkbands_dmean2_9  \
# 0                     0.001228                     0.001563
#
#    lowlevel_barkbands_dmean2_10  lowlevel_barkbands_dmean2_11  \
# 0                      0.001136                      0.000974
#
#    lowlevel_barkbands_dmean2_12  lowlevel_barkbands_dmean2_13  \
# 0                      0.000487                      0.000708
#
#    lowlevel_barkbands_dmean2_14  lowlevel_barkbands_dmean2_15  \
# 0                      0.000467                      0.000513
#
#    lowlevel_barkbands_dmean2_16  lowlevel_barkbands_dmean2_17  \
# 0                      0.000587                       0.00026
#
#    lowlevel_barkbands_dmean2_18  lowlevel_barkbands_dmean2_19  \
# 0                      0.000328                      0.000228
#
#    lowlevel_barkbands_dmean2_20  lowlevel_barkbands_dmean2_21  \
# 0                      0.000219                      0.000114
#
#    lowlevel_barkbands_dmean2_22  lowlevel_barkbands_dmean2_23  \
# 0                      0.000096                      0.000128
#
#    lowlevel_barkbands_dmean2_24  lowlevel_barkbands_dmean2_25  \
# 0                       0.00008                      0.000021
#
#    lowlevel_barkbands_dmean2_26  lowlevel_barkbands_dvar_0  \
# 0                  3.046708e-07               3.247660e-08
#
#    lowlevel_barkbands_dvar_1  lowlevel_barkbands_dvar_2  \
# 0                   0.000034                   0.000018
#
#    lowlevel_barkbands_dvar_3  lowlevel_barkbands_dvar_4  \
# 0                   0.000023                   0.000019
#
#    lowlevel_barkbands_dvar_5  lowlevel_barkbands_dvar_6  \
# 0                   0.000004                   0.000007
#
#    lowlevel_barkbands_dvar_7  lowlevel_barkbands_dvar_8  \
# 0                   0.000005                   0.000006
#
#    lowlevel_barkbands_dvar_9  lowlevel_barkbands_dvar_10  \
# 0                   0.000005                    0.000004
#
#    lowlevel_barkbands_dvar_11  lowlevel_barkbands_dvar_12  \
# 0                    0.000002                6.705084e-07
#
#    lowlevel_barkbands_dvar_13  lowlevel_barkbands_dvar_14  \
# 0                9.690582e-07                5.668290e-07
#
#    lowlevel_barkbands_dvar_15  lowlevel_barkbands_dvar_16  \
# 0                4.597743e-07                4.383334e-07
#
#    lowlevel_barkbands_dvar_17  lowlevel_barkbands_dvar_18  \
# 0                1.517523e-07                2.823435e-07
#
#    lowlevel_barkbands_dvar_19  lowlevel_barkbands_dvar_20  \
# 0                1.438047e-07                1.345740e-07
#
#    lowlevel_barkbands_dvar_21  lowlevel_barkbands_dvar_22  \
# 0                5.134643e-08                7.720951e-08
#
#    lowlevel_barkbands_dvar_23  lowlevel_barkbands_dvar_24  \
# 0                1.619658e-07                9.728013e-08
#
#    lowlevel_barkbands_dvar_25  lowlevel_barkbands_dvar_26  \
# 0                6.807539e-09                6.656277e-13
#
#    lowlevel_barkbands_dvar2_0  lowlevel_barkbands_dvar2_1  \
# 0                7.325916e-08                    0.000094
#
#    lowlevel_barkbands_dvar2_2  lowlevel_barkbands_dvar2_3  \
# 0                    0.000049                     0.00006
#
#    lowlevel_barkbands_dvar2_4  lowlevel_barkbands_dvar2_5  \
# 0                    0.000051                    0.000009
#
#    lowlevel_barkbands_dvar2_6  lowlevel_barkbands_dvar2_7  \
# 0                    0.000014                    0.000012
#
#    lowlevel_barkbands_dvar2_8  lowlevel_barkbands_dvar2_9  \
# 0                    0.000014                    0.000014
#
#    lowlevel_barkbands_dvar2_10  lowlevel_barkbands_dvar2_11  \
# 0                      0.00001                     0.000006
#
#    lowlevel_barkbands_dvar2_12  lowlevel_barkbands_dvar2_13  \
# 0                     0.000002                     0.000002
#
#    lowlevel_barkbands_dvar2_14  lowlevel_barkbands_dvar2_15  \
# 0                     0.000001                     0.000001
#
#    lowlevel_barkbands_dvar2_16  lowlevel_barkbands_dvar2_17  \
# 0                     0.000001                 3.584668e-07
#
#    lowlevel_barkbands_dvar2_18  lowlevel_barkbands_dvar2_19  \
# 0                 6.438316e-07                 3.617354e-07
#
#    lowlevel_barkbands_dvar2_20  lowlevel_barkbands_dvar2_21  \
# 0                 2.842518e-07                 1.007477e-07
#
#    lowlevel_barkbands_dvar2_22  lowlevel_barkbands_dvar2_23  \
# 0                 1.742110e-07                 3.800986e-07
#
#    lowlevel_barkbands_dvar2_24  lowlevel_barkbands_dvar2_25  \
# 0                 1.922001e-07                 1.129840e-08
#
#    lowlevel_barkbands_dvar2_26  lowlevel_barkbands_max_0  \
# 0                 1.564532e-12                  0.001308
#
#    lowlevel_barkbands_max_1  lowlevel_barkbands_max_2  \
# 0                  0.038829                  0.039794
#
#    lowlevel_barkbands_max_3  lowlevel_barkbands_max_4  \
# 0                  0.053553                  0.056927
#
#    lowlevel_barkbands_max_5  lowlevel_barkbands_max_6  \
# 0                  0.033581                  0.049927
#
#    lowlevel_barkbands_max_7  lowlevel_barkbands_max_8  \
# 0                  0.051511                  0.058313
#
#    lowlevel_barkbands_max_9  lowlevel_barkbands_max_10  \
# 0                  0.036611                    0.05188
#
#    lowlevel_barkbands_max_11  lowlevel_barkbands_max_12  \
# 0                   0.031073                   0.025124
#
#    lowlevel_barkbands_max_13  lowlevel_barkbands_max_14  \
# 0                   0.033775                     0.0171
#
#    lowlevel_barkbands_max_15  lowlevel_barkbands_max_16  \
# 0                   0.013831                   0.018794
#
#    lowlevel_barkbands_max_17  lowlevel_barkbands_max_18  \
# 0                   0.013111                   0.012563
#
#    lowlevel_barkbands_max_19  lowlevel_barkbands_max_20  \
# 0                   0.012296                   0.012426
#
#    lowlevel_barkbands_max_21  lowlevel_barkbands_max_22  \
# 0                   0.009735                   0.013608
#
#    lowlevel_barkbands_max_23  lowlevel_barkbands_max_24  \
# 0                   0.017519                   0.012392
#
#    lowlevel_barkbands_max_25  lowlevel_barkbands_max_26  \
# 0                   0.003794                   0.000026
#
#    lowlevel_barkbands_mean_0  lowlevel_barkbands_mean_1  \
# 0                    0.00006                   0.002586
#
#    lowlevel_barkbands_mean_2  lowlevel_barkbands_mean_3  \
# 0                   0.001712                   0.001784
#
#    lowlevel_barkbands_mean_4  lowlevel_barkbands_mean_5  \
# 0                   0.004152                   0.001935
#
#    lowlevel_barkbands_mean_6  lowlevel_barkbands_mean_7  \
# 0                    0.00268                   0.001244
#
#    lowlevel_barkbands_mean_8  lowlevel_barkbands_mean_9  \
# 0                   0.001243                   0.001415
#
#    lowlevel_barkbands_mean_10  lowlevel_barkbands_mean_11  \
# 0                    0.001007                    0.000964
#
#    lowlevel_barkbands_mean_12  lowlevel_barkbands_mean_13  \
# 0                    0.000468                    0.000693
#
#    lowlevel_barkbands_mean_14  lowlevel_barkbands_mean_15  \
# 0                    0.000476                    0.000507
#
#    lowlevel_barkbands_mean_16  lowlevel_barkbands_mean_17  \
# 0                    0.000554                     0.00026
#
#    lowlevel_barkbands_mean_18  lowlevel_barkbands_mean_19  \
# 0                    0.000355                    0.000271
#
#    lowlevel_barkbands_mean_20  lowlevel_barkbands_mean_21  \
# 0                    0.000285                     0.00015
#
#    lowlevel_barkbands_mean_22  lowlevel_barkbands_mean_23  \
# 0                    0.000118                    0.000136
#
#    lowlevel_barkbands_mean_24  lowlevel_barkbands_mean_25  \
# 0                    0.000088                    0.000023
#
#    lowlevel_barkbands_mean_26  lowlevel_barkbands_median_0  \
# 0                1.490452e-07                     0.000001
#
#    lowlevel_barkbands_median_1  lowlevel_barkbands_median_2  \
# 0                     0.000205                     0.000475
#
#    lowlevel_barkbands_median_3  lowlevel_barkbands_median_4  \
# 0                     0.000405                     0.002608
#
#    lowlevel_barkbands_median_5  lowlevel_barkbands_median_6  \
# 0                     0.001008                     0.001106
#
#    lowlevel_barkbands_median_7  lowlevel_barkbands_median_8  \
# 0                     0.000341                     0.000284
#
#    lowlevel_barkbands_median_9  lowlevel_barkbands_median_10  \
# 0                     0.000256                      0.000216
#
#    lowlevel_barkbands_median_11  lowlevel_barkbands_median_12  \
# 0                      0.000315                       0.00021
#
#    lowlevel_barkbands_median_13  lowlevel_barkbands_median_14  \
# 0                      0.000292                      0.000177
#
#    lowlevel_barkbands_median_15  lowlevel_barkbands_median_16  \
# 0                      0.000246                      0.000303
#
#    lowlevel_barkbands_median_17  lowlevel_barkbands_median_18  \
# 0                      0.000124                      0.000113
#
#    lowlevel_barkbands_median_19  lowlevel_barkbands_median_20  \
# 0                      0.000104                      0.000081
#
#    lowlevel_barkbands_median_21  lowlevel_barkbands_median_22  \
# 0                      0.000028                      0.000026
#
#    lowlevel_barkbands_median_23  lowlevel_barkbands_median_24  \
# 0                      0.000032                      0.000012
#
#    lowlevel_barkbands_median_25  lowlevel_barkbands_median_26  \
# 0                      0.000004                  2.942766e-09
#
#    lowlevel_barkbands_min_0  lowlevel_barkbands_min_1  \
# 0              1.351906e-24              4.318318e-24
#
#    lowlevel_barkbands_min_2  lowlevel_barkbands_min_3  \
# 0              2.742991e-24              1.298077e-24
#
#    lowlevel_barkbands_min_4  lowlevel_barkbands_min_5  \
# 0              7.451312e-24              1.134111e-23
#
#    lowlevel_barkbands_min_6  lowlevel_barkbands_min_7  \
# 0              1.232417e-23              1.008602e-23
#
#    lowlevel_barkbands_min_8  lowlevel_barkbands_min_9  \
# 0              2.074584e-23              3.172762e-23
#
#    lowlevel_barkbands_min_10  lowlevel_barkbands_min_11  \
# 0               3.046205e-23               3.566869e-23
#
#    lowlevel_barkbands_min_12  lowlevel_barkbands_min_13  \
# 0               2.699631e-23               6.658082e-23
#
#    lowlevel_barkbands_min_14  lowlevel_barkbands_min_15  \
# 0               4.228990e-23               7.560506e-23
#
#    lowlevel_barkbands_min_16  lowlevel_barkbands_min_17  \
# 0               7.730501e-23               1.219626e-22
#
#    lowlevel_barkbands_min_18  lowlevel_barkbands_min_19  \
# 0               9.543024e-23               1.762186e-22
#
#    lowlevel_barkbands_min_20  lowlevel_barkbands_min_21  \
# 0               2.694220e-22               3.007049e-22
#
#    lowlevel_barkbands_min_22  lowlevel_barkbands_min_23  \
# 0               4.411075e-22               6.769555e-22
#
#    lowlevel_barkbands_min_24  lowlevel_barkbands_min_25  \
# 0               1.016230e-21               1.331918e-21
#
#    lowlevel_barkbands_min_26  lowlevel_barkbands_var_0  \
# 0               2.072347e-21              3.143128e-08
#
#    lowlevel_barkbands_var_1  lowlevel_barkbands_var_2  \
# 0                  0.000035                  0.000014
#
#    lowlevel_barkbands_var_3  lowlevel_barkbands_var_4  \
# 0                  0.000019                  0.000024
#
#    lowlevel_barkbands_var_5  lowlevel_barkbands_var_6  \
# 0                  0.000008                  0.000021
#
#    lowlevel_barkbands_var_7  lowlevel_barkbands_var_8  \
# 0                  0.000009                  0.000015
#
#    lowlevel_barkbands_var_9  lowlevel_barkbands_var_10  \
# 0                  0.000009                   0.000008
#
#    lowlevel_barkbands_var_11  lowlevel_barkbands_var_12  \
# 0                   0.000005               9.675254e-07
#
#    lowlevel_barkbands_var_13  lowlevel_barkbands_var_14  \
# 0                   0.000002                   0.000001
#
#    lowlevel_barkbands_var_15  lowlevel_barkbands_var_16  \
# 0               8.094121e-07               6.977932e-07
#
#    lowlevel_barkbands_var_17  lowlevel_barkbands_var_18  \
# 0               2.636985e-07               6.141822e-07
#
#    lowlevel_barkbands_var_19  lowlevel_barkbands_var_20  \
# 0               3.016599e-07               3.472156e-07
#
#    lowlevel_barkbands_var_21  lowlevel_barkbands_var_22  \
# 0               1.246266e-07               1.189614e-07
#
#    lowlevel_barkbands_var_23  lowlevel_barkbands_var_24  \
# 0               2.663455e-07               2.080052e-07
#
#    lowlevel_barkbands_var_25  lowlevel_barkbands_var_26  \
# 0               1.883128e-08               6.683125e-13
#
#    lowlevel_erbbands_dmean_0  lowlevel_erbbands_dmean_1  \
# 0                   0.058848                   0.688918
#
#    lowlevel_erbbands_dmean_2  lowlevel_erbbands_dmean_3  \
# 0                   1.996627                   3.897173
#
#    lowlevel_erbbands_dmean_4  lowlevel_erbbands_dmean_5  \
# 0                   8.101627                   7.833286
#
#    lowlevel_erbbands_dmean_6  lowlevel_erbbands_dmean_7  \
# 0                    8.54607                    8.49789
#
#    lowlevel_erbbands_dmean_8  lowlevel_erbbands_dmean_9  \
# 0                  19.480509                  16.334915
#
#    lowlevel_erbbands_dmean_10  lowlevel_erbbands_dmean_11  \
# 0                   20.375727                   18.451117
#
#    lowlevel_erbbands_dmean_12  lowlevel_erbbands_dmean_13  \
# 0                   15.503161                   38.770103
#
#    lowlevel_erbbands_dmean_14  lowlevel_erbbands_dmean_15  \
# 0                   24.203562                   23.829309
#
#    lowlevel_erbbands_dmean_16  lowlevel_erbbands_dmean_17  \
# 0                    13.72056                     20.2106
#
#    lowlevel_erbbands_dmean_18  lowlevel_erbbands_dmean_19  \
# 0                   17.333994                   12.928209
#
#    lowlevel_erbbands_dmean_20  lowlevel_erbbands_dmean_21  \
# 0                   17.263584                    14.88956
#
#    lowlevel_erbbands_dmean_22  lowlevel_erbbands_dmean_23  \
# 0                   11.492886                    8.148756
#
#    lowlevel_erbbands_dmean_24  lowlevel_erbbands_dmean_25  \
# 0                   11.168535                    7.006898
#
#    lowlevel_erbbands_dmean_26  lowlevel_erbbands_dmean_27  \
# 0                    6.035033                    5.248535
#
#    lowlevel_erbbands_dmean_28  lowlevel_erbbands_dmean_29  \
# 0                    2.976386                    2.625004
#
#    lowlevel_erbbands_dmean_30  lowlevel_erbbands_dmean_31  \
# 0                    1.782563                    1.684476
#
#    lowlevel_erbbands_dmean_32  lowlevel_erbbands_dmean_33  \
# 0                    1.488675                    0.795577
#
#    lowlevel_erbbands_dmean_34  lowlevel_erbbands_dmean_35  \
# 0                    0.329711                    0.114104
#
#    lowlevel_erbbands_dmean_36  lowlevel_erbbands_dmean_37  \
# 0                    0.019452                    0.001488
#
#    lowlevel_erbbands_dmean_38  lowlevel_erbbands_dmean_39  \
# 0                    0.000038                    0.000012
#
#    lowlevel_erbbands_dmean2_0  lowlevel_erbbands_dmean2_1  \
# 0                    0.092237                    1.247282
#
#    lowlevel_erbbands_dmean2_2  lowlevel_erbbands_dmean2_3  \
# 0                    3.477184                    6.587276
#
#    lowlevel_erbbands_dmean2_4  lowlevel_erbbands_dmean2_5  \
# 0                   13.887143                   12.718959
#
#    lowlevel_erbbands_dmean2_6  lowlevel_erbbands_dmean2_7  \
# 0                   13.050732                   13.284191
#
#    lowlevel_erbbands_dmean2_8  lowlevel_erbbands_dmean2_9  \
# 0                   27.863537                   24.628464
#
#    lowlevel_erbbands_dmean2_10  lowlevel_erbbands_dmean2_11  \
# 0                    32.076603                    28.064611
#
#    lowlevel_erbbands_dmean2_12  lowlevel_erbbands_dmean2_13  \
# 0                    24.185101                     61.74715
#
#    lowlevel_erbbands_dmean2_14  lowlevel_erbbands_dmean2_15  \
# 0                    37.940506                     38.36618
#
#    lowlevel_erbbands_dmean2_16  lowlevel_erbbands_dmean2_17  \
# 0                    21.946257                    31.699892
#
#    lowlevel_erbbands_dmean2_18  lowlevel_erbbands_dmean2_19  \
# 0                    26.864529                    21.364771
#
#    lowlevel_erbbands_dmean2_20  lowlevel_erbbands_dmean2_21  \
# 0                    28.136354                     24.32877
#
#    lowlevel_erbbands_dmean2_22  lowlevel_erbbands_dmean2_23  \
# 0                    18.807121                    12.668578
#
#    lowlevel_erbbands_dmean2_24  lowlevel_erbbands_dmean2_25  \
# 0                    17.269924                    10.776053
#
#    lowlevel_erbbands_dmean2_26  lowlevel_erbbands_dmean2_27  \
# 0                     9.103612                      7.64097
#
#    lowlevel_erbbands_dmean2_28  lowlevel_erbbands_dmean2_29  \
# 0                     4.207888                     3.649124
#
#    lowlevel_erbbands_dmean2_30  lowlevel_erbbands_dmean2_31  \
# 0                     2.487361                     2.514316
#
#    lowlevel_erbbands_dmean2_32  lowlevel_erbbands_dmean2_33  \
# 0                     2.234121                     1.174469
#
#    lowlevel_erbbands_dmean2_34  lowlevel_erbbands_dmean2_35  \
# 0                     0.460274                     0.153137
#
#    lowlevel_erbbands_dmean2_36  lowlevel_erbbands_dmean2_37  \
# 0                     0.026295                     0.002078
#
#    lowlevel_erbbands_dmean2_38  lowlevel_erbbands_dmean2_39  \
# 0                     0.000051                     0.000017
#
#    lowlevel_erbbands_dvar_0  lowlevel_erbbands_dvar_1  \
# 0                  0.018209                  2.511265
#
#    lowlevel_erbbands_dvar_2  lowlevel_erbbands_dvar_3  \
# 0                  23.88413                 78.864929
#
#    lowlevel_erbbands_dvar_4  lowlevel_erbbands_dvar_5  \
# 0                425.115356                167.656265
#
#    lowlevel_erbbands_dvar_6  lowlevel_erbbands_dvar_7  \
# 0                258.188812                237.831146
#
#    lowlevel_erbbands_dvar_8  lowlevel_erbbands_dvar_9  \
# 0               1347.405518               1473.269287
#
#    lowlevel_erbbands_dvar_10  lowlevel_erbbands_dvar_11  \
# 0                3033.569336                3022.839844
#
#    lowlevel_erbbands_dvar_12  lowlevel_erbbands_dvar_13  \
# 0                1635.907227                8713.446289
#
#    lowlevel_erbbands_dvar_14  lowlevel_erbbands_dvar_15  \
# 0                3961.487305                3583.114258
#
#    lowlevel_erbbands_dvar_16  lowlevel_erbbands_dvar_17  \
# 0                1040.505249                2459.940674
#
#    lowlevel_erbbands_dvar_18  lowlevel_erbbands_dvar_19  \
# 0                1459.079712                 927.171875
#
#    lowlevel_erbbands_dvar_20  lowlevel_erbbands_dvar_21  \
# 0                1240.162354                 860.390076
#
#    lowlevel_erbbands_dvar_22  lowlevel_erbbands_dvar_23  \
# 0                 595.158569                 283.574768
#
#    lowlevel_erbbands_dvar_24  lowlevel_erbbands_dvar_25  \
# 0                1068.330933                 251.817276
#
#    lowlevel_erbbands_dvar_26  lowlevel_erbbands_dvar_27  \
# 0                 224.234695                 183.500885
#
#    lowlevel_erbbands_dvar_28  lowlevel_erbbands_dvar_29  \
# 0                  54.896343                 125.194405
#
#    lowlevel_erbbands_dvar_30  lowlevel_erbbands_dvar_31  \
# 0                  51.105072                  44.960915
#
#    lowlevel_erbbands_dvar_32  lowlevel_erbbands_dvar_33  \
# 0                  67.856003                  22.240055
#
#    lowlevel_erbbands_dvar_34  lowlevel_erbbands_dvar_35  \
# 0                   3.964741                   0.442451
#
#    lowlevel_erbbands_dvar_36  lowlevel_erbbands_dvar_37  \
# 0                   0.009471                   0.000044
#
#    lowlevel_erbbands_dvar_38  lowlevel_erbbands_dvar_39  \
# 0               2.466651e-08               3.272848e-10
#
#    lowlevel_erbbands_dvar2_0  lowlevel_erbbands_dvar2_1  \
# 0                   0.036957                   7.304461
#
#    lowlevel_erbbands_dvar2_2  lowlevel_erbbands_dvar2_3  \
# 0                  65.916458                 207.701843
#
#    lowlevel_erbbands_dvar2_4  lowlevel_erbbands_dvar2_5  \
# 0                1177.460205                 448.663177
#
#    lowlevel_erbbands_dvar2_6  lowlevel_erbbands_dvar2_7  \
# 0                 632.026184                 562.437195
#
#    lowlevel_erbbands_dvar2_8  lowlevel_erbbands_dvar2_9  \
# 0                2500.744141                3368.732422
#
#    lowlevel_erbbands_dvar2_10  lowlevel_erbbands_dvar2_11  \
# 0                 7291.530762                  6433.32373
#
# ...
#
#    tonal_hpcp_dmean_19  tonal_hpcp_dmean_20  tonal_hpcp_dmean_21  \
# 0             0.077594             0.129861              0.18987
#
#    tonal_hpcp_dmean_22  tonal_hpcp_dmean_23  tonal_hpcp_dmean_24  \
# 0             0.177213             0.105863             0.072545
#
#    tonal_hpcp_dmean_25  tonal_hpcp_dmean_26  tonal_hpcp_dmean_27  \
# 0             0.059957             0.057394             0.067587
#
#    tonal_hpcp_dmean_28  tonal_hpcp_dmean_29  tonal_hpcp_dmean_30  \
# 0             0.071024             0.067904             0.073666
#
#    tonal_hpcp_dmean_31  tonal_hpcp_dmean_32  tonal_hpcp_dmean_33  \
# 0             0.062274             0.064457             0.101867
#
#    tonal_hpcp_dmean_34  tonal_hpcp_dmean_35  tonal_hpcp_dmean2_0  \
# 0             0.156561             0.209913             0.372345
#
#    tonal_hpcp_dmean2_1  tonal_hpcp_dmean2_2  tonal_hpcp_dmean2_3  \
# 0              0.36164             0.262957             0.193207
#
#    tonal_hpcp_dmean2_4  tonal_hpcp_dmean2_5  tonal_hpcp_dmean2_6  \
# 0             0.178128             0.194508             0.232074
#
#    tonal_hpcp_dmean2_7  tonal_hpcp_dmean2_8  tonal_hpcp_dmean2_9  \
# 0             0.188461             0.121664             0.108513
#
#    tonal_hpcp_dmean2_10  tonal_hpcp_dmean2_11  tonal_hpcp_dmean2_12  \
# 0               0.10055              0.119052              0.149109
#
#    tonal_hpcp_dmean2_13  tonal_hpcp_dmean2_14  tonal_hpcp_dmean2_15  \
# 0              0.151349              0.177807              0.211939
#
#    tonal_hpcp_dmean2_16  tonal_hpcp_dmean2_17  tonal_hpcp_dmean2_18  \
# 0              0.203584              0.136973              0.114936
#
#    tonal_hpcp_dmean2_19  tonal_hpcp_dmean2_20  tonal_hpcp_dmean2_21  \
# 0              0.139915              0.227559              0.331053
#
#    tonal_hpcp_dmean2_22  tonal_hpcp_dmean2_23  tonal_hpcp_dmean2_24  \
# 0              0.311291              0.191501              0.134905
#
#    tonal_hpcp_dmean2_25  tonal_hpcp_dmean2_26  tonal_hpcp_dmean2_27  \
# 0              0.111086              0.104233              0.117463
#
#    tonal_hpcp_dmean2_28  tonal_hpcp_dmean2_29  tonal_hpcp_dmean2_30  \
# 0              0.124208              0.118277              0.127743
#
#    tonal_hpcp_dmean2_31  tonal_hpcp_dmean2_32  tonal_hpcp_dmean2_33  \
# 0              0.108611              0.115349              0.183329
#
#    tonal_hpcp_dmean2_34  tonal_hpcp_dmean2_35  tonal_hpcp_dvar_0  \
# 0              0.283322              0.361082           0.061629
#
#    tonal_hpcp_dvar_1  tonal_hpcp_dvar_2  tonal_hpcp_dvar_3  tonal_hpcp_dvar_4  \
# 0           0.049313           0.040844            0.03897             0.0356
#
#    tonal_hpcp_dvar_5  tonal_hpcp_dvar_6  tonal_hpcp_dvar_7  tonal_hpcp_dvar_8  \
# 0            0.03517           0.045146           0.029805           0.020821
#
#    tonal_hpcp_dvar_9  tonal_hpcp_dvar_10  tonal_hpcp_dvar_11  \
# 0           0.019643             0.01637             0.01873
#
#    tonal_hpcp_dvar_12  tonal_hpcp_dvar_13  tonal_hpcp_dvar_14  \
# 0              0.0256            0.026309            0.026305
#
#    tonal_hpcp_dvar_15  tonal_hpcp_dvar_16  tonal_hpcp_dvar_17  \
# 0             0.03888            0.032373            0.018687
#
#    tonal_hpcp_dvar_18  tonal_hpcp_dvar_19  tonal_hpcp_dvar_20  \
# 0            0.017608            0.023986             0.03683
#
#    tonal_hpcp_dvar_21  tonal_hpcp_dvar_22  tonal_hpcp_dvar_23  \
# 0            0.058653            0.053945            0.038907
#
#    tonal_hpcp_dvar_24  tonal_hpcp_dvar_25  tonal_hpcp_dvar_26  \
# 0            0.029233            0.023948            0.020277
#
#    tonal_hpcp_dvar_27  tonal_hpcp_dvar_28  tonal_hpcp_dvar_29  \
# 0            0.022333            0.024619            0.019602
#
#    tonal_hpcp_dvar_30  tonal_hpcp_dvar_31  tonal_hpcp_dvar_32  \
# 0            0.023064            0.017737            0.018867
#
#    tonal_hpcp_dvar_33  tonal_hpcp_dvar_34  tonal_hpcp_dvar_35  \
# 0            0.031382              0.0566            0.050803
#
#    tonal_hpcp_dvar2_0  tonal_hpcp_dvar2_1  tonal_hpcp_dvar2_2  \
# 0            0.142772            0.122653            0.110183
#
#    tonal_hpcp_dvar2_3  tonal_hpcp_dvar2_4  tonal_hpcp_dvar2_5  \
# 0            0.105754            0.097374            0.094466
#
#    tonal_hpcp_dvar2_6  tonal_hpcp_dvar2_7  tonal_hpcp_dvar2_8  \
# 0            0.110632            0.073786            0.055672
#
#    tonal_hpcp_dvar2_9  tonal_hpcp_dvar2_10  tonal_hpcp_dvar2_11  \
# 0            0.054174             0.044496             0.049302
#
#    tonal_hpcp_dvar2_12  tonal_hpcp_dvar2_13  tonal_hpcp_dvar2_14  \
# 0             0.063648             0.066352             0.069588
#
#    tonal_hpcp_dvar2_15  tonal_hpcp_dvar2_16  tonal_hpcp_dvar2_17  \
# 0             0.089369             0.080654             0.052081
#
#    tonal_hpcp_dvar2_18  tonal_hpcp_dvar2_19  tonal_hpcp_dvar2_20  \
# 0              0.04735             0.064394             0.099106
#
#    tonal_hpcp_dvar2_21  tonal_hpcp_dvar2_22  tonal_hpcp_dvar2_23  \
# 0             0.147118             0.142624             0.107388
#
#    tonal_hpcp_dvar2_24  tonal_hpcp_dvar2_25  tonal_hpcp_dvar2_26  \
# 0             0.081797             0.067974             0.057031
#
#    tonal_hpcp_dvar2_27  tonal_hpcp_dvar2_28  tonal_hpcp_dvar2_29  \
# 0             0.057498             0.064388             0.054011
#
#    tonal_hpcp_dvar2_30  tonal_hpcp_dvar2_31  tonal_hpcp_dvar2_32  \
# 0               0.0587             0.047527             0.051687
#
#    tonal_hpcp_dvar2_33  tonal_hpcp_dvar2_34  tonal_hpcp_dvar2_35  \
# 0             0.084803             0.153534             0.136045
#
#    tonal_hpcp_max_0  tonal_hpcp_max_1  tonal_hpcp_max_2  tonal_hpcp_max_3  \
# 0                 1                 1                 1                 1
#
#    tonal_hpcp_max_4  tonal_hpcp_max_5  tonal_hpcp_max_6  tonal_hpcp_max_7  \
# 0                 1                 1                 1                 1
#
#    tonal_hpcp_max_8  tonal_hpcp_max_9  tonal_hpcp_max_10  tonal_hpcp_max_11  \
# 0                 1                 1                  1                  1
#
#    tonal_hpcp_max_12  tonal_hpcp_max_13  tonal_hpcp_max_14  tonal_hpcp_max_15  \
# 0                  1                  1                  1                  1
#
#    tonal_hpcp_max_16  tonal_hpcp_max_17  tonal_hpcp_max_18  tonal_hpcp_max_19  \
# 0                  1                  1                  1                  1
#
#    tonal_hpcp_max_20  tonal_hpcp_max_21  tonal_hpcp_max_22  tonal_hpcp_max_23  \
# 0                  1                  1                  1                  1
#
#    tonal_hpcp_max_24  tonal_hpcp_max_25  tonal_hpcp_max_26  tonal_hpcp_max_27  \
# 0                  1                  1                  1                  1
#
#    tonal_hpcp_max_28  tonal_hpcp_max_29  tonal_hpcp_max_30  tonal_hpcp_max_31  \
# 0                  1                  1                  1                  1
#
#    tonal_hpcp_max_32  tonal_hpcp_max_33  tonal_hpcp_max_34  tonal_hpcp_max_35  \
# 0                  1                  1                  1                  1
#
#    tonal_hpcp_mean_0  tonal_hpcp_mean_1  tonal_hpcp_mean_2  tonal_hpcp_mean_3  \
# 0           0.528508           0.400879           0.143969           0.085097
#
#    tonal_hpcp_mean_4  tonal_hpcp_mean_5  tonal_hpcp_mean_6  tonal_hpcp_mean_7  \
# 0            0.07753             0.1109           0.164137           0.128132
#
#    tonal_hpcp_mean_8  tonal_hpcp_mean_9  tonal_hpcp_mean_10  \
# 0           0.064709            0.05129            0.048397
#
#    tonal_hpcp_mean_11  tonal_hpcp_mean_12  tonal_hpcp_mean_13  \
# 0            0.074547            0.118188            0.112805
#
#    tonal_hpcp_mean_14  tonal_hpcp_mean_15  tonal_hpcp_mean_16  \
# 0            0.146357             0.24785            0.196365
#
#    tonal_hpcp_mean_17  tonal_hpcp_mean_18  tonal_hpcp_mean_19  \
# 0            0.080979             0.05847             0.06537
#
#    tonal_hpcp_mean_20  tonal_hpcp_mean_21  tonal_hpcp_mean_22  \
# 0            0.142555            0.275461             0.23106
#
#    tonal_hpcp_mean_23  tonal_hpcp_mean_24  tonal_hpcp_mean_25  \
# 0            0.090437            0.052263            0.042315
#
#    tonal_hpcp_mean_26  tonal_hpcp_mean_27  tonal_hpcp_mean_28  \
# 0            0.047648            0.073569            0.074356
#
#    tonal_hpcp_mean_29  tonal_hpcp_mean_30  tonal_hpcp_mean_31  \
# 0            0.069035            0.082843            0.064708
#
#    tonal_hpcp_mean_32  tonal_hpcp_mean_33  tonal_hpcp_mean_34  \
# 0            0.057119            0.089424             0.13116
#
#    tonal_hpcp_mean_35  tonal_hpcp_median_0  tonal_hpcp_median_1  \
# 0            0.302838             0.478469             0.340044
#
#    tonal_hpcp_median_2  tonal_hpcp_median_3  tonal_hpcp_median_4  \
# 0             0.052114             0.013842             0.012186
#
#    tonal_hpcp_median_5  tonal_hpcp_median_6  tonal_hpcp_median_7  \
# 0             0.028392             0.048411             0.040772
#
#    tonal_hpcp_median_8  tonal_hpcp_median_9  tonal_hpcp_median_10  \
# 0             0.016706             0.011199              0.011447
#
#    tonal_hpcp_median_11  tonal_hpcp_median_12  tonal_hpcp_median_13  \
# 0              0.026949              0.044776              0.038881
#
#    tonal_hpcp_median_14  tonal_hpcp_median_15  tonal_hpcp_median_16  \
# 0               0.05576              0.076498              0.063999
#
#    tonal_hpcp_median_17  tonal_hpcp_median_18  tonal_hpcp_median_19  \
# 0              0.033355              0.019735              0.015677
#
#    tonal_hpcp_median_20  tonal_hpcp_median_21  tonal_hpcp_median_22  \
# 0              0.063911              0.134199              0.109835
#
#    tonal_hpcp_median_23  tonal_hpcp_median_24  tonal_hpcp_median_25  \
# 0              0.027422              0.007475              0.006324
#
#    tonal_hpcp_median_26  tonal_hpcp_median_27  tonal_hpcp_median_28  \
# 0              0.010497              0.017275              0.017017
#
#    tonal_hpcp_median_29  tonal_hpcp_median_30  tonal_hpcp_median_31  \
# 0              0.017879              0.015987              0.014615
#
#    tonal_hpcp_median_32  tonal_hpcp_median_33  tonal_hpcp_median_34  \
# 0               0.01876              0.028879              0.041011
#
#    tonal_hpcp_median_35  tonal_hpcp_min_0  tonal_hpcp_min_1  tonal_hpcp_min_2  \
# 0              0.226319                 0                 0                 0
#
#    tonal_hpcp_min_3  tonal_hpcp_min_4  tonal_hpcp_min_5  tonal_hpcp_min_6  \
# 0                 0                 0                 0                 0
#
#    tonal_hpcp_min_7  tonal_hpcp_min_8  tonal_hpcp_min_9  tonal_hpcp_min_10  \
# 0                 0                 0                 0                  0
#
#    tonal_hpcp_min_11  tonal_hpcp_min_12  tonal_hpcp_min_13  tonal_hpcp_min_14  \
# 0                  0                  0                  0                  0
#
#    tonal_hpcp_min_15  tonal_hpcp_min_16  tonal_hpcp_min_17  tonal_hpcp_min_18  \
# 0                  0                  0                  0                  0
#
#    tonal_hpcp_min_19  tonal_hpcp_min_20  tonal_hpcp_min_21  tonal_hpcp_min_22  \
# 0                  0                  0                  0                  0
#
#    tonal_hpcp_min_23  tonal_hpcp_min_24  tonal_hpcp_min_25  tonal_hpcp_min_26  \
# 0                  0                  0                  0                  0
#
#    tonal_hpcp_min_27  tonal_hpcp_min_28  tonal_hpcp_min_29  tonal_hpcp_min_30  \
# 0                  0                  0                  0                  0
#
#    tonal_hpcp_min_31  tonal_hpcp_min_32  tonal_hpcp_min_33  tonal_hpcp_min_34  \
# 0                  0                  0                  0                  0
#
#    tonal_hpcp_min_35  tonal_hpcp_var_0  tonal_hpcp_var_1  tonal_hpcp_var_2  \
# 0                  0           0.15219          0.107682          0.043199
#
#    tonal_hpcp_var_3  tonal_hpcp_var_4  tonal_hpcp_var_5  tonal_hpcp_var_6  \
# 0          0.032385          0.029467          0.038325          0.069386
#
#    tonal_hpcp_var_7  tonal_hpcp_var_8  tonal_hpcp_var_9  tonal_hpcp_var_10  \
# 0          0.043312          0.021385          0.016858           0.013847
#
#    tonal_hpcp_var_11  tonal_hpcp_var_12  tonal_hpcp_var_13  tonal_hpcp_var_14  \
# 0           0.020315           0.041864           0.039831           0.041642
#
#    tonal_hpcp_var_15  tonal_hpcp_var_16  tonal_hpcp_var_17  tonal_hpcp_var_18  \
# 0           0.113541           0.073386           0.019292           0.014713
#
#    tonal_hpcp_var_19  tonal_hpcp_var_20  tonal_hpcp_var_21  tonal_hpcp_var_22  \
# 0           0.020253           0.038376            0.09796           0.073762
#
#    tonal_hpcp_var_23  tonal_hpcp_var_24  tonal_hpcp_var_25  tonal_hpcp_var_26  \
# 0           0.030049           0.020002           0.016021           0.015436
#
#    tonal_hpcp_var_27  tonal_hpcp_var_28  tonal_hpcp_var_29  tonal_hpcp_var_30  \
# 0           0.027415           0.028421           0.019953           0.032962
#
#    tonal_hpcp_var_31  tonal_hpcp_var_32  tonal_hpcp_var_33  tonal_hpcp_var_34  \
# 0           0.020868           0.014389           0.026209           0.048074
#
#    tonal_hpcp_var_35  tonal_chords_histogram_0  tonal_chords_histogram_1  \
# 0           0.074006                 18.619791                         0
#
#    tonal_chords_histogram_2  tonal_chords_histogram_3  \
# 0                  9.296875                         0
#
#    tonal_chords_histogram_4  tonal_chords_histogram_5  \
# 0                  0.989583                  1.901042
#
#    tonal_chords_histogram_6  tonal_chords_histogram_7  \
# 0                  0.572917                  13.28125
#
#    tonal_chords_histogram_8  tonal_chords_histogram_9  \
# 0                         0                 53.932293
#
#    tonal_chords_histogram_10  tonal_chords_histogram_11  \
# 0                   1.015625                   0.104167
#
#    tonal_chords_histogram_12  tonal_chords_histogram_13  \
# 0                          0                          0
#
#    tonal_chords_histogram_14  tonal_chords_histogram_15  \
# 0                          0                          0
#
#    tonal_chords_histogram_16  tonal_chords_histogram_17  \
# 0                          0                          0
#
#    tonal_chords_histogram_18  tonal_chords_histogram_19  \
# 0                          0                          0
#
#    tonal_chords_histogram_20  tonal_chords_histogram_21  \
# 0                          0                          0
#
#    tonal_chords_histogram_22  tonal_chords_histogram_23  tonal_thpcp_0  \
# 0                   0.286458                          0              1
#
#    tonal_thpcp_1  tonal_thpcp_2  tonal_thpcp_3  tonal_thpcp_4  tonal_thpcp_5  \
# 0       0.758511       0.272406       0.161013       0.146696       0.209836
#
#    tonal_thpcp_6  tonal_thpcp_7  tonal_thpcp_8  tonal_thpcp_9  tonal_thpcp_10  \
# 0       0.310567        0.24244       0.122437       0.097047        0.091574
#
#    tonal_thpcp_11  tonal_thpcp_12  tonal_thpcp_13  tonal_thpcp_14  \
# 0        0.141052        0.223626        0.213441        0.276925
#
#    tonal_thpcp_15  tonal_thpcp_16  tonal_thpcp_17  tonal_thpcp_18  \
# 0        0.468961        0.371546        0.153222        0.110632
#
#    tonal_thpcp_19  tonal_thpcp_20  tonal_thpcp_21  tonal_thpcp_22  \
# 0        0.123687        0.269731        0.521206        0.437193
#
#    tonal_thpcp_23  tonal_thpcp_24  tonal_thpcp_25  tonal_thpcp_26  \
# 0        0.171118        0.098888        0.080064        0.090156
#
#    tonal_thpcp_27  tonal_thpcp_28  tonal_thpcp_29  tonal_thpcp_30  \
# 0        0.139201         0.14069        0.130622        0.156748
#
#    tonal_thpcp_31  tonal_thpcp_32  tonal_thpcp_33  tonal_thpcp_34  \
# 0        0.122435        0.108076          0.1692         0.24817
#
#    tonal_thpcp_35 tonal_chords_key tonal_chords_scale tonal_key_key  \
# 0        0.573006                A              major             D
#
#   tonal_key_scale
# 0           minor

# %%
df_single_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Columns: 2651 entries, lowlevel_average_loudness to tonal_key_scale
# dtypes: float64(2492), int64(155), object(4)
# memory usage: 20.7+ KB
