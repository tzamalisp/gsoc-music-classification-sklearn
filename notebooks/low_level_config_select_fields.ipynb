# %%
import glob, os
import pathlib
import json
import yaml

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import collections
from pprint import pprint

from dotty_dict import dotty

# %matplotlib inline

# %%
# avoid the module's method call deprecation
try:
    collectionsAbc = collections.abc
except AttributeError:
    collectionsAbc = collections

# %% [markdown]
# Configuring Juputer's options to present more things to the output.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Functions to use

# %% [markdown]
# ## Function to fully flatten each json file

# %%
def flatten_dict_full(d, sep="_"):
    obj = collections.OrderedDict()

    def recurse(t, parent_key=""):
        
        if isinstance(t, list):
            for i in range(len(t)):
                recurse(t[i], parent_key + sep + str(i) if parent_key else str(i))
        elif isinstance(t,dict):
            for k, v in t.items():
                recurse(v, parent_key + sep + k if parent_key else k)
        else:
            obj[parent_key] = t
    recurse(d)

    return obj

# %%
path_app = os.getcwd()

# %%
# path_app = os.path.join(os.path.abspath(os.getcwd()), os.pardir)
# # path = os.path.join(path, 'danceability', 'features', 'mp3')
# print('Current path:', path_app)
# print('Type:', type(path_app))

# %%
with open(os.path.join(path_app, 'project_danceability.yaml'), 'r') as conf_stream:
    try:
        config_data = yaml.safe_load(conf_stream)
    except yaml.YAMLError as exc:
        print(exc)

# %%
config_data
# Out:
# {'templateVersion': '2.1-beta2',
#  'className': 'test_danceability',
#  'datasetsDirectory': '/data/train_results_danceability/datasets',
#  'resultsDirectory': '/data/train_results_danceability/results',
#  'filelist': '/data/datasets/danceability/metadata/filelist_sig.yaml',
#  'groundtruth': '/data/datasets/danceability/metadata/modified_groundtruth.yaml',
#  'seed': 1593182276.72,
#  'clusterMode': True,
#  'excludedDescriptors': ['metadata.tags*'],
#  'failOnUnmatched': False,
#  'preprocessing': {'raw': [],
#   'basic': [{'transfo': 'remove',
#     'params': {'descriptorNames': ['metadata.*',
#       '*dmean*',
#       '*dvar*',
#       '*.min',
#       '*.max',
#       '*cov',
#       'tonal.thpcp',
#       'lowlevel.spectral_energyband_high.*',
#       'lowlevel.silence_rate*']}},
#    {'transfo': 'enumerate',
#     'params': {'descriptorNames': ['tonal.chords_key',
#       'tonal.chords_scale',
#       'tonal.key_key',
#       'tonal.key_scale']}}],
#   'lowlevel': [{'transfo': 'remove',
#     'params': {'descriptorNames': ['metadata.*',
#       '*dmean*',
#       '*dvar*',
#       '*.min',
#       '*.max',
#       '*cov',
#       'tonal.thpcp',
#       'lowlevel.spectral_energyband_high.*',
#       'lowlevel.silence_rate*']}},
#    {'transfo': 'enumerate',
#     'params': {'descriptorNames': ['tonal.chords_key',
#       'tonal.chords_scale',
#       'tonal.key_key',
#       'tonal.key_scale']}},
#    {'transfo': 'select', 'params': {'descriptorNames': 'lowlevel*'}}],
#   'nobands': [{'transfo': 'remove',
#     'params': {'descriptorNames': ['metadata.*',
#       '*dmean*',
#       '*dvar*',
#       '*.min',
#       '*.max',
#       '*cov',
#       'tonal.thpcp',
#       'lowlevel.spectral_energyband_high.*',
#       'lowlevel.silence_rate*']}},
#    {'transfo': 'enumerate',
#     'params': {'descriptorNames': ['tonal.chords_key',
#       'tonal.chords_scale',
#       'tonal.key_key',
#       'tonal.key_scale']}},
#    {'transfo': 'remove',
#     'params': {'descriptorNames': ['barkbands*',
#       '*energyband*',
#       'melbands*',
#       'erbbands*']}}],
#   'normalized': [{'transfo': 'remove',
#     'params': {'descriptorNames': ['metadata.*',
#       '*dmean*',
#       '*dvar*',
#       '*.min',
#       '*.max',
#       '*cov',
#       'tonal.thpcp',
#       'lowlevel.spectral_energyband_high.*',
#       'lowlevel.silence_rate*']}},
#    {'transfo': 'enumerate',
#     'params': {'descriptorNames': ['tonal.chords_key',
#       'tonal.chords_scale',
#       'tonal.key_key',
#       'tonal.key_scale']}},
#    {'transfo': 'normalize'}],
#   'gaussianized': [{'transfo': 'remove',
#     'params': {'descriptorNames': ['metadata.*',
#       '*dmean*',
#       '*dvar*',
#       '*.min',
#       '*.max',
#       '*cov',
#       'tonal.thpcp',
#       'lowlevel.spectral_energyband_high.*',
#       'lowlevel.silence_rate*']}},
#    {'transfo': 'enumerate',
#     'params': {'descriptorNames': ['tonal.chords_key',
#       'tonal.chords_scale',
#       'tonal.key_key',
#       'tonal.key_scale']}},
#    {'transfo': 'normalize'},
#    {'transfo': 'gaussianize', 'params': {'descriptorNames': 'lowlevel.*'}}],
#   'mfcc': [{'transfo': 'remove',
#     'params': {'descriptorNames': ['metadata.*',
#       '*dmean*',
#       '*dvar*',
#       '*.min',
#       '*.max',
#       '*cov',
#       'tonal.thpcp',
#       'lowlevel.spectral_energyband_high.*',
#       'lowlevel.silence_rate*']}},
#    {'transfo': 'enumerate',
#     'params': {'descriptorNames': ['tonal.chords_key',
#       'tonal.chords_scale',
#       'tonal.key_key',
#       'tonal.key_scale']}},
#    {'transfo': 'select', 'params': {'descriptorNames': 'lowlevel.mfcc*'}}]},
#  'classifiers': {'svm': [{'preprocessing': ['basic',
#      'lowlevel',
#      'nobands',
#      'normalized',
#      'gaussianized',
#      'mfcc'],
#     'type': ['C-SVC'],
#     'kernel': ['poly', 'RBF'],
#     'C': [-5, -3, -1, 1, 3, 5, 7, 9, 11],
#     'gamma': [3, 1, -1, -3, -5, -7, -9, -11],
#     'balanceClasses': [False, True]}]},
#  'evaluations': {'nfoldcrossvalidation': [{'nfold': [5]}]}}

# %%
exclude_descriptors = config_data["excludedDescriptors"]

# %%
exclude_descriptors
# Out:
# ['metadata.tags*']

# %%
config_data["preprocessing"]["basic"]
# Out:
# [{'transfo': 'remove',
#   'params': {'descriptorNames': ['metadata.*',
#     '*dmean*',
#     '*dvar*',
#     '*.min',
#     '*.max',
#     '*cov',
#     'tonal.thpcp',
#     'lowlevel.spectral_energyband_high.*',
#     'lowlevel.silence_rate*']}},
#  {'transfo': 'enumerate',
#   'params': {'descriptorNames': ['tonal.chords_key',
#     'tonal.chords_scale',
#     'tonal.key_key',
#     'tonal.key_scale']}}]

# %%
config_data["preprocessing"]["basic"][0]["transfo"]
# Out:
# 'remove'

# %%
config_data["preprocessing"]["basic"][0]["params"]["descriptorNames"]
# Out:
# ['metadata.*',
#  '*dmean*',
#  '*dvar*',
#  '*.min',
#  '*.max',
#  '*cov',
#  'tonal.thpcp',
#  'lowlevel.spectral_energyband_high.*',
#  'lowlevel.silence_rate*']

# %%
type(config_data["preprocessing"]["basic"][0]["params"]["descriptorNames"])
# Out:
# list

# %%
remove_keys_list = config_data["preprocessing"]["basic"][0]["params"]["descriptorNames"]

# %% [markdown]
# # Load Data GroundTruth

# %% [markdown]
# ## Path declaration

# %%
path_obj = pathlib.Path().absolute()
path_obj
# Out:
# PosixPath('/Users/pantelistzamalis/Desktop/google2020/gsoc_ml_infrastructure/notebooks')

# %%
path_app_data = os.path.join(os.path.abspath(os.getcwd()), os.pardir)
# path = os.path.join(path, 'danceability', 'features', 'mp3')
# print('Current path:', path_app)
print('Type:', type(path_app_data))
print("Path:", path_app_data)
# Out:
# Type: <class 'str'>
# Path: /Users/pantelistzamalis/Desktop/google2020/gsoc_ml_infrastructure/notebooks/..

# %% [markdown]
# ## Count all the JSON data included in files

# %%
counter = 0
for root, dirs, files in os.walk(path_app_data):
    for file in files:
        if(file.endswith(".json")):
#             print(os.path.join(root,file))
            counter += 1
            
print('counted json files:', counter)
# Out:
# counted json files: 10461

# %% [markdown]
# ## Load the GroundTruth file

# %%
with open(os.path.join(path_app_data, 'acousticbrainz-datasets/danceability/metadata/groundtruth.yaml'), 'r') as stream:
    try:
        groundTr_data = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# %%
len(groundTr_data['groundTruth'].keys())
# Out:
# 225

# %% [markdown]
# ## Check the unique folders with tracks and sort them alphabetically

# %%
labeled_tracks = groundTr_data['groundTruth']

# %% [markdown]
# ### Split the keys in Folder - Track Name

# %%
folders = []
for key in labeled_tracks:
    key = key.split('/')
    folders.append(key[0])

# %%
print(folders[:15])
# Out:
# ['Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Alternative', 'Blues', 'Blues', 'Blues', 'Blues', 'Blues', 'Blues']

# %% [markdown]
# ### Check the folders

# %%
folders = set(folders)
folders = list(folders)
folders.sort()
folders
# Out:
# ['Alternative',
#  'Blues',
#  'Classical',
#  'Country',
#  'Dance and House',
#  'Folk and New Age',
#  'Hip-Hop and Rap',
#  'House & Garage and Grime',
#  'Jazz',
#  'Jungle and D&B',
#  'Latin',
#  'Pop',
#  'R&B and Soul',
#  'Reggae',
#  'Rock and Metal',
#  'Techno and Electro',
#  'Vocal and Acapella']

# %% [markdown]
# ## Class Name retrieved from GT file

# %%
class_name = groundTr_data['className']

# %%
class_name
# Out:
# 'danceability'

# %% [markdown]
# ## Load a DF containing the tracks from the features path and the info retrieved from the GT file

# %%
path_features = os.path.join(path_app_data, 'acousticbrainz-datasets/danceability', 'features', 'mp3')

# %%
# path_features

# %%
tracks = []
for key, value in labeled_tracks.items():
    track_dict = {}
    key = key.split('/')
    path_tracks = os.path.join(path_features, key[0])
    for f_name in os.listdir(path_tracks):
        if f_name.startswith(key[1]):
            track_dict['genre_category'] = key[0]
            track_dict['track'] = key[1]
            track_dict['track_path'] = os.path.join(path_features, key[0], f_name)
            track_dict['danceability'] = value
    tracks.append(track_dict)

# %%
len(tracks)
# Out:
# 225

# %% [markdown]
# DF that includes the tracks

# %%
df_tracks = pd.DataFrame(data=tracks)

# %% [markdown]
# Plot the track's paths

# %%
df_tracks.head()
# Out:
#   genre_category                                          track  \
# 0    Alternative         02 Happy Birthday - Altered Images.mp3
# 1    Alternative                03 How Soon Is Now - Smiths.mp3
# 2    Alternative  04 Pearly Dewdrops' Drops - Cocteau Twins.mp3
# 3    Alternative                 06 Mr Brightside - Killers.mp3
# 4    Alternative                           06 Song 2 - Blur.mp3
#
#                                                                                                                                                                                         track_path  \
# 0         /Users/pantelistzamalis/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/02 Happy Birthday - Altered Images.mp3.json
# 1                /Users/pantelistzamalis/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/03 How Soon Is Now - Smiths.mp3.json
# 2  /Users/pantelistzamalis/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/04 Pearly Dewdrops' Drops - Cocteau Twins.mp3.json
# 3                 /Users/pantelistzamalis/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/06 Mr Brightside - Killers.mp3.json
# 4                           /Users/pantelistzamalis/Desktop/google2020/gsoc_ml_infrastructure/notebooks/../acousticbrainz-datasets/danceability/features/mp3/Alternative/06 Song 2 - Blur.mp3.json
#
#     danceability
# 0      danceable
# 1  not_danceable
# 2  not_danceable
# 3      danceable
# 4      danceable

# %% [markdown]
# Check the className distribution of the data based on the 'genre_category'

# %% [markdown]
# Data distribution based on the genres

# %%
df_tracks['genre_category'].value_counts()
# Out:
# Jungle and D&B              22
# Latin                       22
# Dance and House             21
# Hip-Hop and Rap             19
# Vocal and Acapella          17
# Techno and Electro          16
# Folk and New Age            16
# Rock and Metal              13
# R&B and Soul                13
# Reggae                      12
# House & Garage and Grime    10
# Alternative                  9
# Blues                        8
# Country                      8
# Pop                          7
# Jazz                         6
# Classical                    6
# Name: genre_category, dtype: int64

# %% [markdown]
# # Load a Single JSON low-level file and handle its data

# %%
with open(df_tracks['track_path'].iloc[0]) as json_file:
    data_feats = json.load(json_file)

# %%
# pprint(data_feats)

# %%
data_feats.keys()
# Out:
# dict_keys(['lowlevel', 'metadata', 'rhythm', 'tonal'])

# %%
data_feats["metadata"]["tags"]
# Out:
# {'file_name': '02 Happy Birthday - Altered Images.mp3',
#  'album': ['John Peel - A Tribute [UK] Disc 2'],
#  'albumartist': ['Various Artists'],
#  'artist': ['Various Artists'],
#  'date': ['2005'],
#  'genre': ['Rock/Pop'],
#  'label': ['WSM'],
#  'length': ['178320'],
#  'title': ['Happy Birthday - Altered Images'],
#  'tracknumber': ['2']}

# %%
data_feats_dotty = dotty(data_feats)

# %%
data_feats_dotty["metadata.tags"]
# Out:
# {'file_name': '02 Happy Birthday - Altered Images.mp3',
#  'album': ['John Peel - A Tribute [UK] Disc 2'],
#  'albumartist': ['Various Artists'],
#  'artist': ['Various Artists'],
#  'date': ['2005'],
#  'genre': ['Rock/Pop'],
#  'label': ['WSM'],
#  'length': ['178320'],
#  'title': ['Happy Birthday - Altered Images'],
#  'tracknumber': ['2']}

# %%
remove_keys_list
# Out:
# ['metadata.*',
#  '*dmean*',
#  '*dvar*',
#  '*.min',
#  '*.max',
#  '*cov',
#  'tonal.thpcp',
#  'lowlevel.spectral_energyband_high.*',
#  'lowlevel.silence_rate*']

# %%
data_feats_dotty["lowlevel.spectral_energyband_high"]
# Out:
# {'dmean': 0.000430126703577,
#  'dmean2': 0.000582747336011,
#  'dvar': 1.32549780574e-06,
#  'dvar2': 2.6748007258e-06,
#  'max': 0.0408168584108,
#  'mean': 0.000924074323848,
#  'median': 0.000307242153212,
#  'min': 7.17486931364e-21,
#  'var': 3.44317140843e-06}

# %%
# def remove_keys(keys_list):
#     for item in keys_list:
#         if item.endswith(".*"):
#             item = item.replace(".*", "")
# #             del data_feats_dotty[item]
#             print(data_feats_dotty[item])
#         elif item.startswith(""):
#         else:
#             del data_feats_dotty[item]

# %%
# remove_keys(remove_keys_list)

# %%
# data_feats_dotty["lowlevel.silence_rate"]

# %%
data_feats_dotty["lowlevel.spectral_energyband_high"]
# Out:
# {'dmean': 0.000430126703577,
#  'dmean2': 0.000582747336011,
#  'dvar': 1.32549780574e-06,
#  'dvar2': 2.6748007258e-06,
#  'max': 0.0408168584108,
#  'mean': 0.000924074323848,
#  'median': 0.000307242153212,
#  'min': 7.17486931364e-21,
#  'var': 3.44317140843e-06}

# %%
for k, v in data_feats.items():
    for k1, v1 in v.items():
        key_list = []
        key_list.append(k)
        key_list.append(k1)
        keys_united = ".".join(key_list)
        print(keys_united)
# Out:
# lowlevel.average_loudness
# lowlevel.barkbands_crest
# lowlevel.barkbands_flatness_db
# lowlevel.barkbands_kurtosis
# lowlevel.barkbands_skewness
# lowlevel.barkbands_spread
# lowlevel.dissonance
# lowlevel.dynamic_complexity
# lowlevel.erbbands_crest
# lowlevel.erbbands_flatness_db
# lowlevel.erbbands_kurtosis
# lowlevel.erbbands_skewness
# lowlevel.erbbands_spread
# lowlevel.hfc
# lowlevel.melbands_crest
# lowlevel.melbands_flatness_db
# lowlevel.melbands_kurtosis
# lowlevel.melbands_skewness
# lowlevel.melbands_spread
# lowlevel.pitch_salience
# lowlevel.silence_rate_20dB
# lowlevel.silence_rate_30dB
# lowlevel.silence_rate_60dB
# lowlevel.spectral_centroid
# lowlevel.spectral_complexity
# lowlevel.spectral_decrease
# lowlevel.spectral_energy
# lowlevel.spectral_energyband_high
# lowlevel.spectral_energyband_low
# lowlevel.spectral_energyband_middle_high
# lowlevel.spectral_energyband_middle_low
# lowlevel.spectral_entropy
# lowlevel.spectral_flux
# lowlevel.spectral_kurtosis
# lowlevel.spectral_rms
# lowlevel.spectral_rolloff
# lowlevel.spectral_skewness
# lowlevel.spectral_spread
# lowlevel.spectral_strongpeak
# lowlevel.zerocrossingrate
# lowlevel.barkbands
# lowlevel.erbbands
# lowlevel.gfcc
# lowlevel.melbands
# lowlevel.mfcc
# lowlevel.spectral_contrast_coeffs
# lowlevel.spectral_contrast_valleys
# metadata.audio_properties
# metadata.tags
# metadata.version
# rhythm.beats_count
# rhythm.beats_loudness
# rhythm.bpm
# rhythm.bpm_histogram_first_peak_bpm
# rhythm.bpm_histogram_first_peak_spread
# rhythm.bpm_histogram_first_peak_weight
# rhythm.bpm_histogram_second_peak_bpm
# rhythm.bpm_histogram_second_peak_spread
# rhythm.bpm_histogram_second_peak_weight
# rhythm.danceability
# rhythm.onset_rate
# rhythm.beats_loudness_band_ratio
# rhythm.beats_position
# tonal.chords_changes_rate
# tonal.chords_number_rate
# tonal.chords_strength
# tonal.hpcp_entropy
# tonal.key_strength
# tonal.tuning_diatonic_strength
# tonal.tuning_equal_tempered_deviation
# tonal.tuning_frequency
# tonal.tuning_nontempered_energy_ratio
# tonal.hpcp
# tonal.chords_histogram
# tonal.thpcp
# tonal.chords_key
# tonal.chords_scale
# tonal.key_key
# tonal.key_scale

# %%
flatten_data_feats = flatten_dict_full(data_feats)

# %%
flatten_data_feats= dict(flatten_data_feats)

# %%
flatten_data_feats
# Out:
# {'lowlevel_average_loudness': 0.940232157707,
#  'lowlevel_barkbands_crest_dmean': 2.76665973663,
#  'lowlevel_barkbands_crest_dmean2': 4.44829654694,
#  'lowlevel_barkbands_crest_dvar': 5.74580621719,
#  'lowlevel_barkbands_crest_dvar2': 14.9876413345,
#  'lowlevel_barkbands_crest_max': 26.7228469849,
#  'lowlevel_barkbands_crest_mean': 10.8071289062,
#  'lowlevel_barkbands_crest_median': 9.6913394928,
#  'lowlevel_barkbands_crest_min': 2.79826569557,
#  'lowlevel_barkbands_crest_var': 24.1222038269,
#  'lowlevel_barkbands_flatness_db_dmean': 0.0237202681601,
#  'lowlevel_barkbands_flatness_db_dmean2': 0.0359584279358,
#  'lowlevel_barkbands_flatness_db_dvar': 0.000525934854522,
#  'lowlevel_barkbands_flatness_db_dvar2': 0.0011579785496,
#  'lowlevel_barkbands_flatness_db_max': 0.627937674522,
#  'lowlevel_barkbands_flatness_db_mean': 0.176746591926,
#  'lowlevel_barkbands_flatness_db_median': 0.146083265543,
#  'lowlevel_barkbands_flatness_db_min': 0.0408386327326,
#  'lowlevel_barkbands_flatness_db_var': 0.0109738511965,
#  'lowlevel_barkbands_kurtosis_dmean': 4.54691982269,
#  'lowlevel_barkbands_kurtosis_dmean2': 6.84590864182,
#  'lowlevel_barkbands_kurtosis_dvar': 239.760787964,
#  'lowlevel_barkbands_kurtosis_dvar2': 517.971374512,
#  'lowlevel_barkbands_kurtosis_max': 635.369262695,
#  'lowlevel_barkbands_kurtosis_mean': 6.76269578934,
#  'lowlevel_barkbands_kurtosis_median': 1.55632472038,
#  'lowlevel_barkbands_kurtosis_min': -1.92447042465,
#  'lowlevel_barkbands_kurtosis_var': 522.650878906,
#  'lowlevel_barkbands_skewness_dmean': 0.626882314682,
#  'lowlevel_barkbands_skewness_dmean2': 0.939088046551,
#  'lowlevel_barkbands_skewness_dvar': 0.54220020771,
#  'lowlevel_barkbands_skewness_dvar2': 1.1847602129,
#  'lowlevel_barkbands_skewness_max': 18.3686237335,
#  'lowlevel_barkbands_skewness_mean': 1.5351549387,
#  'lowlevel_barkbands_skewness_median': 1.27241706848,
#  'lowlevel_barkbands_skewness_min': -3.23566484451,
#  'lowlevel_barkbands_skewness_var': 2.18761944771,
#  'lowlevel_barkbands_spread_dmean': 5.13634681702,
#  'lowlevel_barkbands_spread_dmean2': 7.90009689331,
#  'lowlevel_barkbands_spread_dvar': 45.053401947,
#  'lowlevel_barkbands_spread_dvar2': 109.031082153,
#  'lowlevel_barkbands_spread_max': 133.435379028,
#  'lowlevel_barkbands_spread_mean': 19.0258789062,
#  'lowlevel_barkbands_spread_median': 17.5046195984,
#  'lowlevel_barkbands_spread_min': 0.0330036431551,
#  'lowlevel_barkbands_spread_var': 164.326553345,
#  'lowlevel_dissonance_dmean': 0.0244754124433,
#  'lowlevel_dissonance_dmean2': 0.0402562245727,
#  'lowlevel_dissonance_dvar': 0.000792722392362,
#  'lowlevel_dissonance_dvar2': 0.00201370264404,
#  'lowlevel_dissonance_max': 0.499981969595,
#  'lowlevel_dissonance_mean': 0.437223672867,
#  'lowlevel_dissonance_median': 0.460024178028,
#  'lowlevel_dissonance_min': 0.0749529004097,
#  'lowlevel_dissonance_var': 0.00511173671111,
#  'lowlevel_dynamic_complexity': 3.14495134354,
#  'lowlevel_erbbands_crest_dmean': 3.04497861862,
#  'lowlevel_erbbands_crest_dmean2': 4.83319664001,
#  'lowlevel_erbbands_crest_dvar': 8.15985298157,
#  'lowlevel_erbbands_crest_dvar2': 19.592464447,
#  'lowlevel_erbbands_crest_max': 32.3874855042,
#  'lowlevel_erbbands_crest_mean': 10.746547699,
#  'lowlevel_erbbands_crest_median': 9.16017723083,
#  'lowlevel_erbbands_crest_min': 2.31932711601,
#  'lowlevel_erbbands_crest_var': 35.120967865,
#  'lowlevel_erbbands_flatness_db_dmean': 0.021677583456,
#  'lowlevel_erbbands_flatness_db_dmean2': 0.0282148271799,
#  'lowlevel_erbbands_flatness_db_dvar': 0.000464496784844,
#  'lowlevel_erbbands_flatness_db_dvar2': 0.000759973016102,
#  'lowlevel_erbbands_flatness_db_max': 0.590238690376,
#  'lowlevel_erbbands_flatness_db_mean': 0.200973406434,
#  'lowlevel_erbbands_flatness_db_median': 0.182578235865,
#  'lowlevel_erbbands_flatness_db_min': 0.0618669912219,
#  'lowlevel_erbbands_flatness_db_var': 0.00852280668914,
#  'lowlevel_erbbands_kurtosis_dmean': 1.7281255722,
#  'lowlevel_erbbands_kurtosis_dmean2': 2.56068086624,
#  'lowlevel_erbbands_kurtosis_dvar': 20.8409252167,
#  'lowlevel_erbbands_kurtosis_dvar2': 42.7215957642,
#  'lowlevel_erbbands_kurtosis_max': 135.502365112,
#  'lowlevel_erbbands_kurtosis_mean': 2.08520650864,
#  'lowlevel_erbbands_kurtosis_median': -0.119842886925,
#  'lowlevel_erbbands_kurtosis_min': -1.89341616631,
#  'lowlevel_erbbands_kurtosis_var': 64.254737854,
#  'lowlevel_erbbands_skewness_dmean': 0.426052153111,
#  'lowlevel_erbbands_skewness_dmean2': 0.63531178236,
#  'lowlevel_erbbands_skewness_dvar': 0.203250721097,
#  'lowlevel_erbbands_skewness_dvar2': 0.415034025908,
#  'lowlevel_erbbands_skewness_max': 8.91370582581,
#  'lowlevel_erbbands_skewness_mean': 0.557501375675,
#  'lowlevel_erbbands_skewness_median': 0.355854153633,
#  'lowlevel_erbbands_skewness_min': -3.11702728271,
#  'lowlevel_erbbands_skewness_var': 1.22907042503,
#  'lowlevel_erbbands_spread_dmean': 7.85425567627,
#  'lowlevel_erbbands_spread_dmean2': 11.6345262527,
#  'lowlevel_erbbands_spread_dvar': 80.0566101074,
#  'lowlevel_erbbands_spread_dvar2': 170.342407227,
#  'lowlevel_erbbands_spread_max': 140.270980835,
#  'lowlevel_erbbands_spread_mean': 33.961555481,
#  'lowlevel_erbbands_spread_median': 31.566576004,
#  'lowlevel_erbbands_spread_min': 0.390867233276,
#  'lowlevel_erbbands_spread_var': 396.588562012,
#  'lowlevel_hfc_dmean': 6.29407262802,
#  'lowlevel_hfc_dmean2': 8.93891048431,
#  'lowlevel_hfc_dvar': 105.744316101,
#  'lowlevel_hfc_dvar2': 211.105163574,
#  'lowlevel_hfc_max': 302.891662598,
#  'lowlevel_hfc_mean': 21.9112300873,
#  'lowlevel_hfc_median': 17.7403278351,
#  'lowlevel_hfc_min': 1.04955329716e-16,
#  'lowlevel_hfc_var': 418.785491943,
#  'lowlevel_melbands_crest_dmean': 3.65264797211,
#  'lowlevel_melbands_crest_dmean2': 5.98124742508,
#  'lowlevel_melbands_crest_dvar': 10.0448102951,
#  'lowlevel_melbands_crest_dvar2': 26.7923717499,
#  'lowlevel_melbands_crest_max': 34.4276199341,
#  'lowlevel_melbands_crest_mean': 14.9341936111,
#  'lowlevel_melbands_crest_median': 13.7971162796,
#  'lowlevel_melbands_crest_min': 1.00446534157,
#  'lowlevel_melbands_crest_var': 36.0476417542,
#  'lowlevel_melbands_flatness_db_dmean': 0.0277328118682,
#  'lowlevel_melbands_flatness_db_dmean2': 0.0424245521426,
#  'lowlevel_melbands_flatness_db_dvar': 0.00076511799125,
#  'lowlevel_melbands_flatness_db_dvar2': 0.00180588080548,
#  'lowlevel_melbands_flatness_db_max': 0.709166228771,
#  'lowlevel_melbands_flatness_db_mean': 0.219118982553,
#  'lowlevel_melbands_flatness_db_median': 0.18665355444,
#  'lowlevel_melbands_flatness_db_min': 1.72573336954e-07,
#  'lowlevel_melbands_flatness_db_var': 0.0135066239163,
#  'lowlevel_melbands_kurtosis_dmean': 6.59601306915,
#  'lowlevel_melbands_kurtosis_dmean2': 10.333322525,
#  'lowlevel_melbands_kurtosis_dvar': 115.083526611,
#  'lowlevel_melbands_kurtosis_dvar2': 276.52532959,
#  'lowlevel_melbands_kurtosis_max': 200.180053711,
#  'lowlevel_melbands_kurtosis_mean': 10.9813566208,
#  'lowlevel_melbands_kurtosis_median': 5.71410512924,
#  'lowlevel_melbands_kurtosis_min': -1.85252034664,
#  'lowlevel_melbands_kurtosis_var': 237.040222168,
#  'lowlevel_melbands_skewness_dmean': 0.757478475571,
#  'lowlevel_melbands_skewness_dmean2': 1.15908110142,
#  'lowlevel_melbands_skewness_dvar': 0.636685371399,
#  'lowlevel_melbands_skewness_dvar2': 1.47149682045,
#  'lowlevel_melbands_skewness_max': 10.4446630478,
#  'lowlevel_melbands_skewness_mean': 2.23729658127,
#  'lowlevel_melbands_skewness_median': 2.01094198227,
#  'lowlevel_melbands_skewness_min': -2.40719985962,
#  'lowlevel_melbands_skewness_var': 2.18306040764,
#  'lowlevel_melbands_spread_dmean': 7.2725815773,
#  'lowlevel_melbands_spread_dmean2': 11.2846908569,
#  'lowlevel_melbands_spread_dvar': 118.792327881,
#  'lowlevel_melbands_spread_dvar2': 276.609100342,
#  'lowlevel_melbands_spread_max': 248.903457642,
#  'lowlevel_melbands_spread_mean': 22.8541736603,
#  'lowlevel_melbands_spread_median': 20.1140403748,
#  'lowlevel_melbands_spread_min': 0.175563290715,
#  'lowlevel_melbands_spread_var': 378.054748535,
#  'lowlevel_pitch_salience_dmean': 0.0760402083397,
#  'lowlevel_pitch_salience_dmean2': 0.124145798385,
#  'lowlevel_pitch_salience_dvar': 0.0044777803123,
#  'lowlevel_pitch_salience_dvar2': 0.0121702011675,
#  'lowlevel_pitch_salience_max': 0.995829582214,
#  'lowlevel_pitch_salience_mean': 0.548196196556,
#  'lowlevel_pitch_salience_median': 0.559924244881,
#  'lowlevel_pitch_salience_min': 0.0337910242379,
#  'lowlevel_pitch_salience_var': 0.0128761138767,
#  'lowlevel_silence_rate_20dB_dmean': 0,
#  'lowlevel_silence_rate_20dB_dmean2': 0,
#  'lowlevel_silence_rate_20dB_dvar': 0,
#  'lowlevel_silence_rate_20dB_dvar2': 0,
#  'lowlevel_silence_rate_20dB_max': 1,
#  'lowlevel_silence_rate_20dB_mean': 1,
#  'lowlevel_silence_rate_20dB_median': 1,
#  'lowlevel_silence_rate_20dB_min': 1,
#  'lowlevel_silence_rate_20dB_var': 0,
#  'lowlevel_silence_rate_30dB_dmean': 0,
#  'lowlevel_silence_rate_30dB_dmean2': 0,
#  'lowlevel_silence_rate_30dB_dvar': 0,
#  'lowlevel_silence_rate_30dB_dvar2': 0,
#  'lowlevel_silence_rate_30dB_max': 1,
#  'lowlevel_silence_rate_30dB_mean': 1,
#  'lowlevel_silence_rate_30dB_median': 1,
#  'lowlevel_silence_rate_30dB_min': 1,
#  'lowlevel_silence_rate_30dB_var': 0,
#  'lowlevel_silence_rate_60dB_dmean': 0.0203204378486,
#  'lowlevel_silence_rate_60dB_dmean2': 0.0406461693347,
#  'lowlevel_silence_rate_60dB_dvar': 0.0199066121131,
#  'lowlevel_silence_rate_60dB_dvar2': 0.0405537076294,
#  'lowlevel_silence_rate_60dB_max': 1,
#  'lowlevel_silence_rate_60dB_mean': 0.0870018228889,
#  'lowlevel_silence_rate_60dB_median': 0,
#  'lowlevel_silence_rate_60dB_min': 0,
#  'lowlevel_silence_rate_60dB_var': 0.079431347549,
#  'lowlevel_spectral_centroid_dmean': 247.01348877,
#  'lowlevel_spectral_centroid_dmean2': 379.758209229,
#  'lowlevel_spectral_centroid_dvar': 94818.0390625,
#  'lowlevel_spectral_centroid_dvar2': 220693.765625,
#  'lowlevel_spectral_centroid_max': 11838.609375,
#  'lowlevel_spectral_centroid_mean': 1261.01171875,
#  'lowlevel_spectral_centroid_median': 1185.40966797,
#  'lowlevel_spectral_centroid_min': 223.340637207,
#  'lowlevel_spectral_centroid_var': 596974.125,
#  'lowlevel_spectral_complexity_dmean': 3.4826104641,
#  'lowlevel_spectral_complexity_dmean2': 5.16701412201,
#  'lowlevel_spectral_complexity_dvar': 15.2105989456,
#  'lowlevel_spectral_complexity_dvar2': 29.246887207,
#  'lowlevel_spectral_complexity_max': 61,
#  'lowlevel_spectral_complexity_mean': 18.3207874298,
#  'lowlevel_spectral_complexity_median': 19,
#  'lowlevel_spectral_complexity_min': 0,
#  'lowlevel_spectral_complexity_var': 101.436401367,
#  'lowlevel_spectral_decrease_dmean': 2.26293983552e-09,
#  'lowlevel_spectral_decrease_dmean2': 3.41320083308e-09,
#  'lowlevel_spectral_decrease_dvar': 9.36051643235e-18,
#  'lowlevel_spectral_decrease_dvar2': 2.21104715991e-17,
#  'lowlevel_spectral_decrease_max': 1.34742620956e-28,
#  'lowlevel_spectral_decrease_mean': -6.14115513997e-09,
#  'lowlevel_spectral_decrease_median': -5.37961586389e-09,
#  'lowlevel_spectral_decrease_min': -2.997968096e-08,
#  'lowlevel_spectral_decrease_var': 2.08325685426e-17,
#  'lowlevel_spectral_energy_dmean': 0.00890370085835,
#  'lowlevel_spectral_energy_dmean2': 0.0133304046467,
#  'lowlevel_spectral_energy_dvar': 0.000138772258651,
#  'lowlevel_spectral_energy_dvar2': 0.000323175714584,
#  'lowlevel_spectral_energy_max': 0.116705782712,
#  'lowlevel_spectral_energy_mean': 0.0251655559987,
#  'lowlevel_spectral_energy_median': 0.0222192555666,
#  'lowlevel_spectral_energy_min': 9.9338066544e-21,
#  'lowlevel_spectral_energy_var': 0.000334666314302,
#  'lowlevel_spectral_energyband_high_dmean': 0.000430126703577,
#  'lowlevel_spectral_energyband_high_dmean2': 0.000582747336011,
#  'lowlevel_spectral_energyband_high_dvar': 1.32549780574e-06,
#  'lowlevel_spectral_energyband_high_dvar2': 2.6748007258e-06,
#  'lowlevel_spectral_energyband_high_max': 0.0408168584108,
#  'lowlevel_spectral_energyband_high_mean': 0.000924074323848,
#  'lowlevel_spectral_energyband_high_median': 0.000307242153212,
#  'lowlevel_spectral_energyband_high_min': 7.17486931364e-21,
#  'lowlevel_spectral_energyband_high_var': 3.44317140843e-06,
#  'lowlevel_spectral_energyband_low_dmean': 0.00442806910723,
#  'lowlevel_spectral_energyband_low_dmean2': 0.00750040123239,
#  'lowlevel_spectral_energyband_low_dvar': 8.28542688396e-05,
#  'lowlevel_spectral_energyband_low_dvar2': 0.000217223903746,
#  'lowlevel_spectral_energyband_low_max': 0.0706124007702,
#  'lowlevel_spectral_energyband_low_mean': 0.00522342603654,
#  'lowlevel_spectral_energyband_low_median': 0.00134223012719,
#  'lowlevel_spectral_energyband_low_min': 1.94255735733e-23,
#  'lowlevel_spectral_energyband_low_var': 9.23197876546e-05,
#  'lowlevel_spectral_energyband_middle_high_dmean': 0.00238069170155,
#  'lowlevel_spectral_energyband_middle_high_dmean2': 0.00363909848966,
#  'lowlevel_spectral_energyband_middle_high_dvar': 1.1954157344e-05,
#  'lowlevel_spectral_energyband_middle_high_dvar2': 2.73423956969e-05,
#  'lowlevel_spectral_energyband_middle_high_max': 0.0557659715414,
#  'lowlevel_spectral_energyband_middle_high_mean': 0.00676744058728,
#  'lowlevel_spectral_energyband_middle_high_median': 0.00434807455167,
#  'lowlevel_spectral_energyband_middle_high_min': 1.31860516115e-21,
#  'lowlevel_spectral_energyband_middle_high_var': 5.37664636795e-05,
#  'lowlevel_spectral_energyband_middle_low_dmean': 0.00580435106531,
#  'lowlevel_spectral_energyband_middle_low_dmean2': 0.00904081296176,
#  'lowlevel_spectral_energyband_middle_low_dvar': 7.37517912057e-05,
#  'lowlevel_spectral_energyband_middle_low_dvar2': 0.000189538783161,
#  'lowlevel_spectral_energyband_middle_low_max': 0.107317842543,
#  'lowlevel_spectral_energyband_middle_low_mean': 0.0132265016437,
#  'lowlevel_spectral_energyband_middle_low_median': 0.0106701012701,
#  'lowlevel_spectral_energyband_middle_low_min': 1.88736726001e-22,
#  'lowlevel_spectral_energyband_middle_low_var': 0.000120521654026,
#  'lowlevel_spectral_entropy_dmean': 0.197789624333,
#  'lowlevel_spectral_entropy_dmean2': 0.275119423866,
#  'lowlevel_spectral_entropy_dvar': 0.0527928210795,
#  'lowlevel_spectral_entropy_dvar2': 0.100931085646,
#  'lowlevel_spectral_entropy_max': 9.81280994415,
#  'lowlevel_spectral_entropy_mean': 7.22640562057,
#  'lowlevel_spectral_entropy_median': 7.45054960251,
#  'lowlevel_spectral_entropy_min': 3.10021781921,
#  'lowlevel_spectral_entropy_var': 0.874165594578,
#  'lowlevel_spectral_flux_dmean': 0.0268623046577,
#  'lowlevel_spectral_flux_dmean2': 0.0401869900525,
#  'lowlevel_spectral_flux_dvar': 0.000885466753971,
#  'lowlevel_spectral_flux_dvar2': 0.00173417804763,
#  'lowlevel_spectral_flux_max': 0.302327811718,
#  'lowlevel_spectral_flux_mean': 0.0865902379155,
#  'lowlevel_spectral_flux_median': 0.0789195001125,
#  'lowlevel_spectral_flux_min': 6.56688037282e-11,
#  'lowlevel_spectral_flux_var': 0.00292754382826,
#  'lowlevel_spectral_kurtosis_dmean': 4.02609634399,
#  'lowlevel_spectral_kurtosis_dmean2': 6.48006343842,
#  'lowlevel_spectral_kurtosis_dvar': 109.164337158,
#  'lowlevel_spectral_kurtosis_dvar2': 297.492584229,
#  'lowlevel_spectral_kurtosis_max': 315.019927979,
#  'lowlevel_spectral_kurtosis_mean': 11.9508237839,
#  'lowlevel_spectral_kurtosis_median': 4.08150100708,
#  'lowlevel_spectral_kurtosis_min': -1.44001293182,
#  'lowlevel_spectral_kurtosis_var': 822.924194336,
#  'lowlevel_spectral_rms_dmean': 0.000809212913737,
#  'lowlevel_spectral_rms_dmean2': 0.0011676204158,
#  'lowlevel_spectral_rms_dvar': 7.88865349932e-07,
#  'lowlevel_spectral_rms_dvar2': 1.71140061411e-06,
#  'lowlevel_spectral_rms_max': 0.0106704877689,
#  'lowlevel_spectral_rms_mean': 0.00457699177787,
#  'lowlevel_spectral_rms_median': 0.00465589109808,
#  'lowlevel_spectral_rms_min': 3.11312043852e-12,
#  'lowlevel_spectral_rms_var': 3.60279614142e-06,
#  'lowlevel_spectral_rolloff_dmean': 501.416381836,
#  'lowlevel_spectral_rolloff_dmean2': 839.424255371,
#  'lowlevel_spectral_rolloff_dvar': 825722.5625,
#  'lowlevel_spectral_rolloff_dvar2': 1889652.5,
#  'lowlevel_spectral_rolloff_max': 19336.8164062,
#  'lowlevel_spectral_rolloff_mean': 1509.52954102,
#  'lowlevel_spectral_rolloff_median': 1184.32617188,
#  'lowlevel_spectral_rolloff_min': 107.666015625,
#  'lowlevel_spectral_rolloff_var': 2454966.75,
#  'lowlevel_spectral_skewness_dmean': 0.33110293746,
#  'lowlevel_spectral_skewness_dmean2': 0.519605875015,
#  'lowlevel_spectral_skewness_dvar': 0.254660397768,
#  'lowlevel_spectral_skewness_dvar2': 0.593803048134,
#  'lowlevel_spectral_skewness_max': 14.9624567032,
#  'lowlevel_spectral_skewness_mean': 2.0311832428,
#  'lowlevel_spectral_skewness_median': 1.50664067268,
#  'lowlevel_spectral_skewness_min': -0.0831068903208,
#  'lowlevel_spectral_skewness_var': 3.68233251572,
#  'lowlevel_spectral_spread_dmean': 552523.875,
#  'lowlevel_spectral_spread_dmean2': 772800.125,
#  'lowlevel_spectral_spread_dvar': 696362270720,
#  'lowlevel_spectral_spread_dvar2': 1386608197630.0,
#  'lowlevel_spectral_spread_max': 41914944,
#  'lowlevel_spectral_spread_mean': 4172137,
#  'lowlevel_spectral_spread_median': 3934539.25,
#  'lowlevel_spectral_spread_min': 426749.40625,
#  'lowlevel_spectral_spread_var': 5861572345860.0,
#  'lowlevel_spectral_strongpeak_dmean': 0.632493197918,
#  'lowlevel_spectral_strongpeak_dmean2': 1.03771686554,
#  'lowlevel_spectral_strongpeak_dvar': 1.04226398468,
#  'lowlevel_spectral_strongpeak_dvar2': 2.56567788124,
#  'lowlevel_spectral_strongpeak_max': 19.0242023468,
#  'lowlevel_spectral_strongpeak_mean': 1.21334075928,
#  'lowlevel_spectral_strongpeak_median': 0.789027690887,
#  'lowlevel_spectral_strongpeak_min': 0,
#  'lowlevel_spectral_strongpeak_var': 1.75328922272,
#  'lowlevel_erbbands_dvar2_35': 0.686560690403,
#  'lowlevel_erbbands_dvar2_36': 0.0187043789774,
#  'lowlevel_erbbands_dvar2_37': 8.22485453682e-05,
#  'lowlevel_erbbands_dvar2_38': 4.30316369204e-08,
#  'lowlevel_erbbands_dvar2_39': 6.39639508027e-10,
#  'lowlevel_erbbands_max_0': 1.06523120403,
#  'lowlevel_erbbands_max_1': 11.1185646057,
#  'lowlevel_erbbands_max_2': 44.2202453613,
#  'lowlevel_erbbands_max_3': 104.340042114,
#  'lowlevel_erbbands_max_4': 277.504333496,
#  'lowlevel_erbbands_max_5': 162.40335083,
#  'lowlevel_erbbands_max_6': 397.756286621,
#  'lowlevel_erbbands_max_7': 378.060821533,
#  'lowlevel_erbbands_max_8': 759.486450195,
#  'lowlevel_erbbands_max_9': 1127.93286133,
#  'lowlevel_erbbands_max_10': 1247.88757324,
#  'lowlevel_erbbands_max_11': 1666.06835938,
#  'lowlevel_erbbands_max_12': 546.102416992,
#  'lowlevel_erbbands_max_13': 1680.11193848,
#  'lowlevel_erbbands_max_14': 1600.86279297,
#  'lowlevel_erbbands_max_15': 1377.46142578,
#  'lowlevel_erbbands_max_16': 893.447570801,
#  'lowlevel_erbbands_max_17': 1575.77392578,
#  'lowlevel_erbbands_max_18': 934.747497559,
#  'lowlevel_erbbands_max_19': 898.674133301,
#  'lowlevel_erbbands_max_20': 1006.94171143,
#  'lowlevel_erbbands_max_21': 795.637573242,
#  'lowlevel_erbbands_max_22': 654.99395752,
#  'lowlevel_erbbands_max_23': 349.998016357,
#  'lowlevel_erbbands_max_24': 882.060058594,
#  'lowlevel_erbbands_max_25': 428.616485596,
#  'lowlevel_erbbands_max_26': 643.165527344,
#  'lowlevel_erbbands_max_27': 439.124633789,
#  'lowlevel_erbbands_max_28': 276.666534424,
#  'lowlevel_erbbands_max_29': 617.534790039,
#  'lowlevel_erbbands_max_30': 294.042144775,
#  'lowlevel_erbbands_max_31': 182.313018799,
#  'lowlevel_erbbands_max_32': 401.924926758,
#  'lowlevel_erbbands_max_33': 207.266403198,
#  'lowlevel_erbbands_max_34': 112.461624146,
#  'lowlevel_erbbands_max_35': 36.8523521423,
#  'lowlevel_erbbands_max_36': 4.3479552269,
#  'lowlevel_erbbands_max_37': 0.296545684338,
#  'lowlevel_erbbands_max_38': 0.00736534316093,
#  'lowlevel_erbbands_max_39': 0.000551090110093,
#  'lowlevel_erbbands_mean_0': 0.0674086883664,
#  'lowlevel_erbbands_mean_1': 0.609410226345,
#  'lowlevel_erbbands_mean_2': 1.86560022831,
#  'lowlevel_erbbands_mean_3': 4.29848480225,
#  'lowlevel_erbbands_mean_4': 9.92288970947,
#  'lowlevel_erbbands_mean_5': 14.9988794327,
#  'lowlevel_erbbands_mean_6': 16.2407341003,
#  'lowlevel_erbbands_mean_7': 14.4098672867,
#  'lowlevel_erbbands_mean_8': 35.6882667542,
#  'lowlevel_erbbands_mean_9': 28.8443603516,
#  'lowlevel_erbbands_mean_10': 32.2077064514,
#  'lowlevel_gfcc_cov_0_2': -1264.98486328,
#  'lowlevel_gfcc_cov_0_3': 2831.66723633,
#  'lowlevel_gfcc_cov_0_4': 645.739379883,
#  'lowlevel_gfcc_cov_0_5': 1800.73010254,
#  'lowlevel_gfcc_cov_0_6': 104.059257507,
#  'lowlevel_gfcc_cov_0_7': 1403.63256836,
#  'lowlevel_gfcc_cov_0_8': -225.733505249,
#  'lowlevel_gfcc_cov_0_9': 93.6007232666,
#  'lowlevel_gfcc_cov_0_10': -999.673583984,
#  'lowlevel_gfcc_cov_0_11': 28.5594921112,
#  'lowlevel_gfcc_cov_0_12': -392.006469727,
#  'lowlevel_gfcc_cov_1_0': -2067.49658203,
#  'lowlevel_gfcc_cov_1_1': 1420.62548828,
#  'lowlevel_gfcc_cov_1_2': 71.0659103394,
#  'lowlevel_gfcc_cov_1_3': -586.503234863,
#  'lowlevel_gfcc_cov_1_4': 155.696807861,
#  'lowlevel_gfcc_cov_1_5': -468.579498291,
#  'lowlevel_gfcc_cov_1_6': 8.96803474426,
#  'lowlevel_gfcc_cov_1_7': -371.806213379,
#  'lowlevel_gfcc_cov_1_8': 61.5243492126,
#  'lowlevel_gfcc_cov_1_9': -177.440002441,
#  'lowlevel_gfcc_cov_1_10': 188.291503906,
#  'lowlevel_gfcc_cov_1_11': -73.6711883545,
#  'lowlevel_gfcc_cov_1_12': 38.3578834534,
#  'lowlevel_gfcc_cov_2_0': -1264.98486328,
#  'lowlevel_gfcc_cov_2_1': 71.0659103394,
#  'lowlevel_gfcc_cov_2_2': 1199.59033203,
#  'lowlevel_gfcc_cov_2_3': 77.4281082153,
#  'lowlevel_gfcc_cov_2_4': -85.9625778198,
#  'lowlevel_gfcc_cov_2_5': 101.824272156,
#  'lowlevel_gfcc_cov_2_6': -47.3721351624,
#  'lowlevel_gfcc_cov_2_7': -70.0493927002,
#  'lowlevel_gfcc_cov_2_8': 61.9743080139,
#  'lowlevel_gfcc_cov_2_9': 79.9910354614,
#  'lowlevel_gfcc_cov_2_10': 24.3108100891,
#  'lowlevel_gfcc_cov_2_11': 148.143264771,
#  'lowlevel_gfcc_cov_2_12': -89.874671936,
#  'lowlevel_gfcc_cov_3_0': 2831.66723633,
#  ...}

# %%
len(flatten_data_feats.keys())
# Out:
# 3135

# %%
lala = "dsxcdfd_mfcc_dsksds"
lolo = "sadsdsd_alaa_slasad"

# %%
import re

# %%
if re.search("mfcc", lolo):
    print("pattern found")
else:
    print("pattern not found")
# Out:
# pattern not found

# %% [markdown]
# `'metadata.*', '*dmean*', '*dvar*',
# '*.min', '*.max', '*cov',
# 'tonal.thpcp', # because of division by zero
# 'lowlevel.spectral_energyband_high.*', # 0 for low samplerate
# 'lowlevel.silence_rate*' # funky behavior in general`

# %%
len(remove_keys_list)
# Out:
# 9

# %%
remove_keys_list_update = []

# %%
for item in remove_keys_list:
    if item.endswith(".*"):
        item = item.replace(".*", "_")
    elif item.startswith("*."):
        item = item.replace("*.", "_")
    else:
        item = item.replace("*", "")
    item = item.replace(".", "_")
    remove_keys_list_update.append(item)

# %%
remove_keys_list_update
# Out:
# ['metadata_',
#  'dmean',
#  'dvar',
#  '_min',
#  '_max',
#  'cov',
#  'tonal_thpcp',
#  'lowlevel_spectral_energyband_high_',
#  'lowlevel_silence_rate']

# %% [markdown]
# 1) metadata: `metadata.*`

# %%
counter = 0
for key in flatten_data_feats:
    if key.startswith("metadata"):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# metadata_audio_properties_analysis_sample_rate
# metadata_audio_properties_bit_rate
# metadata_audio_properties_equal_loudness
# metadata_audio_properties_length
# metadata_audio_properties_lossless
# metadata_audio_properties_replay_gain
# metadata_audio_properties_sample_rate
# metadata_audio_properties_codec
# metadata_audio_properties_downmix
# metadata_audio_properties_md5_encoded
# metadata_tags_file_name
# metadata_tags_album_0
# metadata_tags_albumartist_0
# metadata_tags_artist_0
# metadata_tags_date_0
# metadata_tags_genre_0
# metadata_tags_label_0
# metadata_tags_length_0
# metadata_tags_title_0
# metadata_tags_tracknumber_0
# metadata_version_essentia
# metadata_version_essentia_git_sha
# metadata_version_extractor
#
# 23

# %% [markdown]
# 2) dmean: `*dmean*`

# %%
counter = 0
for key in flatten_data_feats:
    if re.search("dmean", key):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# lowlevel_barkbands_crest_dmean
# lowlevel_barkbands_crest_dmean2
# lowlevel_barkbands_flatness_db_dmean
# lowlevel_barkbands_flatness_db_dmean2
# lowlevel_barkbands_kurtosis_dmean
# lowlevel_barkbands_kurtosis_dmean2
# lowlevel_barkbands_skewness_dmean
# lowlevel_barkbands_skewness_dmean2
# lowlevel_barkbands_spread_dmean
# lowlevel_barkbands_spread_dmean2
# lowlevel_dissonance_dmean
# lowlevel_dissonance_dmean2
# lowlevel_erbbands_crest_dmean
# lowlevel_erbbands_crest_dmean2
# lowlevel_erbbands_flatness_db_dmean
# lowlevel_erbbands_flatness_db_dmean2
# lowlevel_erbbands_kurtosis_dmean
# lowlevel_erbbands_kurtosis_dmean2
# lowlevel_erbbands_skewness_dmean
# lowlevel_erbbands_skewness_dmean2
# lowlevel_erbbands_spread_dmean
# lowlevel_erbbands_spread_dmean2
# lowlevel_hfc_dmean
# lowlevel_hfc_dmean2
# lowlevel_melbands_crest_dmean
# lowlevel_melbands_crest_dmean2
# lowlevel_melbands_flatness_db_dmean
# lowlevel_melbands_flatness_db_dmean2
# lowlevel_melbands_kurtosis_dmean
# lowlevel_melbands_kurtosis_dmean2
# lowlevel_melbands_skewness_dmean
# lowlevel_melbands_skewness_dmean2
# lowlevel_melbands_spread_dmean
# lowlevel_melbands_spread_dmean2
# lowlevel_pitch_salience_dmean
# lowlevel_pitch_salience_dmean2
# lowlevel_silence_rate_20dB_dmean
# lowlevel_silence_rate_20dB_dmean2
# lowlevel_silence_rate_30dB_dmean
# lowlevel_silence_rate_30dB_dmean2
# lowlevel_silence_rate_60dB_dmean
# lowlevel_silence_rate_60dB_dmean2
# lowlevel_spectral_centroid_dmean
# lowlevel_spectral_centroid_dmean2
# lowlevel_spectral_complexity_dmean
# lowlevel_spectral_complexity_dmean2
# lowlevel_spectral_decrease_dmean
# lowlevel_spectral_decrease_dmean2
# lowlevel_spectral_energy_dmean
# lowlevel_spectral_energy_dmean2
# lowlevel_spectral_energyband_high_dmean
# lowlevel_spectral_energyband_high_dmean2
# lowlevel_spectral_energyband_low_dmean
# lowlevel_spectral_energyband_low_dmean2
# lowlevel_spectral_energyband_middle_high_dmean
# lowlevel_spectral_energyband_middle_high_dmean2
# lowlevel_spectral_energyband_middle_low_dmean
# lowlevel_spectral_energyband_middle_low_dmean2
# lowlevel_spectral_entropy_dmean
# lowlevel_spectral_entropy_dmean2
# lowlevel_spectral_flux_dmean
# lowlevel_spectral_flux_dmean2
# lowlevel_spectral_kurtosis_dmean
# lowlevel_spectral_kurtosis_dmean2
# lowlevel_spectral_rms_dmean
# lowlevel_spectral_rms_dmean2
# lowlevel_spectral_rolloff_dmean
# lowlevel_spectral_rolloff_dmean2
# lowlevel_spectral_skewness_dmean
# lowlevel_spectral_skewness_dmean2
# lowlevel_spectral_spread_dmean
# lowlevel_spectral_spread_dmean2
# lowlevel_spectral_strongpeak_dmean
# lowlevel_spectral_strongpeak_dmean2
# lowlevel_zerocrossingrate_dmean
# lowlevel_zerocrossingrate_dmean2
# lowlevel_barkbands_dmean_0
# lowlevel_barkbands_dmean_1
# lowlevel_barkbands_dmean_2
# lowlevel_barkbands_dmean_3
# lowlevel_barkbands_dmean_4
# lowlevel_barkbands_dmean_5
# lowlevel_barkbands_dmean_6
# lowlevel_barkbands_dmean_7
# lowlevel_barkbands_dmean_8
# lowlevel_barkbands_dmean_9
# lowlevel_barkbands_dmean_10
# lowlevel_barkbands_dmean_11
# lowlevel_barkbands_dmean_12
# lowlevel_barkbands_dmean_13
# lowlevel_barkbands_dmean_14
# lowlevel_barkbands_dmean_15
# lowlevel_barkbands_dmean_16
# lowlevel_barkbands_dmean_17
# lowlevel_barkbands_dmean_18
# lowlevel_barkbands_dmean_19
# lowlevel_barkbands_dmean_20
# lowlevel_barkbands_dmean_21
# lowlevel_barkbands_dmean_22
# lowlevel_barkbands_dmean_23
# lowlevel_barkbands_dmean_24
# lowlevel_barkbands_dmean_25
# lowlevel_barkbands_dmean_26
# lowlevel_barkbands_dmean2_0
# lowlevel_barkbands_dmean2_1
# lowlevel_barkbands_dmean2_2
# lowlevel_barkbands_dmean2_3
# lowlevel_barkbands_dmean2_4
# lowlevel_barkbands_dmean2_5
# lowlevel_barkbands_dmean2_6
# lowlevel_barkbands_dmean2_7
# lowlevel_barkbands_dmean2_8
# lowlevel_barkbands_dmean2_9
# lowlevel_barkbands_dmean2_10
# lowlevel_barkbands_dmean2_11
# lowlevel_barkbands_dmean2_12
# lowlevel_barkbands_dmean2_13
# lowlevel_barkbands_dmean2_14
# lowlevel_barkbands_dmean2_15
# lowlevel_barkbands_dmean2_16
# lowlevel_barkbands_dmean2_17
# lowlevel_barkbands_dmean2_18
# lowlevel_erbbands_dmean2_35
# lowlevel_erbbands_dmean2_36
# lowlevel_erbbands_dmean2_37
# lowlevel_erbbands_dmean2_38
# lowlevel_erbbands_dmean2_39
# lowlevel_melbands_dmean_0
# lowlevel_melbands_dmean_1
# lowlevel_melbands_dmean_2
# lowlevel_melbands_dmean_3
# lowlevel_melbands_dmean_4
# lowlevel_melbands_dmean_5
# lowlevel_melbands_dmean_6
# lowlevel_melbands_dmean_7
# lowlevel_melbands_dmean_8
# lowlevel_melbands_dmean_9
# lowlevel_melbands_dmean_10
# lowlevel_melbands_dmean_11
# lowlevel_melbands_dmean_12
# lowlevel_melbands_dmean_13
# lowlevel_melbands_dmean_14
# lowlevel_melbands_dmean_15
# lowlevel_melbands_dmean_16
# lowlevel_melbands_dmean_17
# lowlevel_melbands_dmean_18
# lowlevel_melbands_dmean_19
# lowlevel_melbands_dmean_20
# lowlevel_melbands_dmean_21
# lowlevel_melbands_dmean_22
# lowlevel_melbands_dmean_23
# lowlevel_melbands_dmean_24
# lowlevel_melbands_dmean_25
# lowlevel_melbands_dmean_26
# lowlevel_melbands_dmean_27
# lowlevel_melbands_dmean_28
# lowlevel_melbands_dmean_29
# lowlevel_melbands_dmean_30
# lowlevel_melbands_dmean_31
# lowlevel_melbands_dmean_32
# lowlevel_melbands_dmean_33
# lowlevel_melbands_dmean_34
# lowlevel_melbands_dmean_35
# lowlevel_melbands_dmean_36
# lowlevel_melbands_dmean_37
# lowlevel_melbands_dmean_38
# lowlevel_melbands_dmean_39
# lowlevel_melbands_dmean2_0
# lowlevel_melbands_dmean2_1
# lowlevel_melbands_dmean2_2
# lowlevel_melbands_dmean2_3
# lowlevel_melbands_dmean2_4
# lowlevel_melbands_dmean2_5
# lowlevel_melbands_dmean2_6
# lowlevel_melbands_dmean2_7
# lowlevel_melbands_dmean2_8
# lowlevel_melbands_dmean2_9
# lowlevel_melbands_dmean2_10
# lowlevel_melbands_dmean2_11
# lowlevel_melbands_dmean2_12
# lowlevel_melbands_dmean2_13
# lowlevel_melbands_dmean2_14
# lowlevel_melbands_dmean2_15
# lowlevel_melbands_dmean2_16
# lowlevel_melbands_dmean2_17
# lowlevel_melbands_dmean2_18
# lowlevel_melbands_dmean2_19
# lowlevel_melbands_dmean2_20
# lowlevel_melbands_dmean2_21
# lowlevel_melbands_dmean2_22
# lowlevel_melbands_dmean2_23
# lowlevel_melbands_dmean2_24
# lowlevel_melbands_dmean2_25
# lowlevel_melbands_dmean2_26
# lowlevel_melbands_dmean2_27
# lowlevel_melbands_dmean2_28
# lowlevel_melbands_dmean2_29
# lowlevel_melbands_dmean2_30
# lowlevel_melbands_dmean2_31
# lowlevel_melbands_dmean2_32
# lowlevel_melbands_dmean2_33
# lowlevel_melbands_dmean2_34
# lowlevel_melbands_dmean2_35
# lowlevel_melbands_dmean2_36
# lowlevel_melbands_dmean2_37
# lowlevel_melbands_dmean2_38
# lowlevel_melbands_dmean2_39
# lowlevel_spectral_contrast_coeffs_dmean_0
# lowlevel_spectral_contrast_coeffs_dmean_1
# lowlevel_spectral_contrast_coeffs_dmean_2
# lowlevel_spectral_contrast_coeffs_dmean_3
# lowlevel_spectral_contrast_coeffs_dmean_4
# lowlevel_spectral_contrast_coeffs_dmean_5
# lowlevel_spectral_contrast_coeffs_dmean2_0
# lowlevel_spectral_contrast_coeffs_dmean2_1
# lowlevel_spectral_contrast_coeffs_dmean2_2
# lowlevel_spectral_contrast_coeffs_dmean2_3
# lowlevel_spectral_contrast_coeffs_dmean2_4
# lowlevel_spectral_contrast_coeffs_dmean2_5
# lowlevel_spectral_contrast_valleys_dmean_0
# lowlevel_spectral_contrast_valleys_dmean_1
# lowlevel_spectral_contrast_valleys_dmean_2
# lowlevel_spectral_contrast_valleys_dmean_3
# lowlevel_spectral_contrast_valleys_dmean_4
# lowlevel_spectral_contrast_valleys_dmean_5
# lowlevel_spectral_contrast_valleys_dmean2_0
# lowlevel_spectral_contrast_valleys_dmean2_1
# lowlevel_spectral_contrast_valleys_dmean2_2
# lowlevel_spectral_contrast_valleys_dmean2_3
# lowlevel_spectral_contrast_valleys_dmean2_4
# lowlevel_spectral_contrast_valleys_dmean2_5
# rhythm_beats_loudness_dmean
# rhythm_beats_loudness_dmean2
# rhythm_bpm_histogram_first_peak_bpm_dmean
# rhythm_bpm_histogram_first_peak_bpm_dmean2
# rhythm_bpm_histogram_first_peak_spread_dmean
# rhythm_bpm_histogram_first_peak_spread_dmean2
# rhythm_bpm_histogram_first_peak_weight_dmean
# rhythm_bpm_histogram_first_peak_weight_dmean2
# rhythm_bpm_histogram_second_peak_bpm_dmean
# rhythm_bpm_histogram_second_peak_bpm_dmean2
# rhythm_bpm_histogram_second_peak_spread_dmean
# rhythm_bpm_histogram_second_peak_spread_dmean2
# rhythm_bpm_histogram_second_peak_weight_dmean
# rhythm_bpm_histogram_second_peak_weight_dmean2
# rhythm_beats_loudness_band_ratio_dmean_0
# rhythm_beats_loudness_band_ratio_dmean_1
# rhythm_beats_loudness_band_ratio_dmean_2
# rhythm_beats_loudness_band_ratio_dmean_3
# rhythm_beats_loudness_band_ratio_dmean_4
# rhythm_beats_loudness_band_ratio_dmean_5
# rhythm_beats_loudness_band_ratio_dmean2_0
# rhythm_beats_loudness_band_ratio_dmean2_1
# rhythm_beats_loudness_band_ratio_dmean2_2
# rhythm_beats_loudness_band_ratio_dmean2_3
# rhythm_beats_loudness_band_ratio_dmean2_4
# rhythm_beats_loudness_band_ratio_dmean2_5
# tonal_chords_strength_dmean
# tonal_chords_strength_dmean2
# tonal_hpcp_entropy_dmean
# tonal_hpcp_entropy_dmean2
# tonal_hpcp_dmean_0
# tonal_hpcp_dmean_1
# tonal_hpcp_dmean_2
# tonal_hpcp_dmean_3
# tonal_hpcp_dmean_4
# tonal_hpcp_dmean_5
# tonal_hpcp_dmean_6
# tonal_hpcp_dmean_7
# tonal_hpcp_dmean_8
# tonal_hpcp_dmean_9
# tonal_hpcp_dmean_10
# tonal_hpcp_dmean_11
# tonal_hpcp_dmean_12
# tonal_hpcp_dmean_13
# tonal_hpcp_dmean_14
# tonal_hpcp_dmean_15
# tonal_hpcp_dmean_16
# tonal_hpcp_dmean_17
# tonal_hpcp_dmean_18
# tonal_hpcp_dmean_19
# tonal_hpcp_dmean_20
# tonal_hpcp_dmean_21
# tonal_hpcp_dmean_22
# tonal_hpcp_dmean_23
# tonal_hpcp_dmean_24
# tonal_hpcp_dmean_25
# tonal_hpcp_dmean_26
# tonal_hpcp_dmean_27
# tonal_hpcp_dmean_28
# tonal_hpcp_dmean_29
# tonal_hpcp_dmean_30
# tonal_hpcp_dmean_31
# tonal_hpcp_dmean_32
# tonal_hpcp_dmean_33
# tonal_hpcp_dmean_34
# tonal_hpcp_dmean_35
# tonal_hpcp_dmean2_0
# tonal_hpcp_dmean2_1
# tonal_hpcp_dmean2_2
# tonal_hpcp_dmean2_3
# tonal_hpcp_dmean2_4
# tonal_hpcp_dmean2_5
# tonal_hpcp_dmean2_6
# tonal_hpcp_dmean2_7
# tonal_hpcp_dmean2_8
# tonal_hpcp_dmean2_9
# tonal_hpcp_dmean2_10
# tonal_hpcp_dmean2_11
# tonal_hpcp_dmean2_12
# tonal_hpcp_dmean2_13
# tonal_hpcp_dmean2_14
# tonal_hpcp_dmean2_15
# tonal_hpcp_dmean2_16
# tonal_hpcp_dmean2_17
# tonal_hpcp_dmean2_18
# tonal_hpcp_dmean2_19
# tonal_hpcp_dmean2_20
# tonal_hpcp_dmean2_21
# tonal_hpcp_dmean2_22
# tonal_hpcp_dmean2_23
# tonal_hpcp_dmean2_24
# tonal_hpcp_dmean2_25
# tonal_hpcp_dmean2_26
# tonal_hpcp_dmean2_27
# tonal_hpcp_dmean2_28
# tonal_hpcp_dmean2_29
# tonal_hpcp_dmean2_30
# tonal_hpcp_dmean2_31
# tonal_hpcp_dmean2_32
# tonal_hpcp_dmean2_33
# tonal_hpcp_dmean2_34
# tonal_hpcp_dmean2_35
#
# 416

# %% [markdown]
# 3) dvar: `*dvar*`

# %%
counter = 0
for key in flatten_data_feats:
    if re.search("dvar", key):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# lowlevel_barkbands_crest_dvar
# lowlevel_barkbands_crest_dvar2
# lowlevel_barkbands_flatness_db_dvar
# lowlevel_barkbands_flatness_db_dvar2
# lowlevel_barkbands_kurtosis_dvar
# lowlevel_barkbands_kurtosis_dvar2
# lowlevel_barkbands_skewness_dvar
# lowlevel_barkbands_skewness_dvar2
# lowlevel_barkbands_spread_dvar
# lowlevel_barkbands_spread_dvar2
# lowlevel_dissonance_dvar
# lowlevel_dissonance_dvar2
# lowlevel_erbbands_crest_dvar
# lowlevel_erbbands_crest_dvar2
# lowlevel_erbbands_flatness_db_dvar
# lowlevel_erbbands_flatness_db_dvar2
# lowlevel_erbbands_kurtosis_dvar
# lowlevel_erbbands_kurtosis_dvar2
# lowlevel_erbbands_skewness_dvar
# lowlevel_erbbands_skewness_dvar2
# lowlevel_erbbands_spread_dvar
# lowlevel_erbbands_spread_dvar2
# lowlevel_hfc_dvar
# lowlevel_hfc_dvar2
# lowlevel_melbands_crest_dvar
# lowlevel_melbands_crest_dvar2
# lowlevel_melbands_flatness_db_dvar
# lowlevel_melbands_flatness_db_dvar2
# lowlevel_melbands_kurtosis_dvar
# lowlevel_melbands_kurtosis_dvar2
# lowlevel_melbands_skewness_dvar
# lowlevel_melbands_skewness_dvar2
# lowlevel_melbands_spread_dvar
# lowlevel_melbands_spread_dvar2
# lowlevel_pitch_salience_dvar
# lowlevel_pitch_salience_dvar2
# lowlevel_silence_rate_20dB_dvar
# lowlevel_silence_rate_20dB_dvar2
# lowlevel_silence_rate_30dB_dvar
# lowlevel_silence_rate_30dB_dvar2
# lowlevel_silence_rate_60dB_dvar
# lowlevel_silence_rate_60dB_dvar2
# lowlevel_spectral_centroid_dvar
# lowlevel_spectral_centroid_dvar2
# lowlevel_spectral_complexity_dvar
# lowlevel_spectral_complexity_dvar2
# lowlevel_spectral_decrease_dvar
# lowlevel_spectral_decrease_dvar2
# lowlevel_spectral_energy_dvar
# lowlevel_spectral_energy_dvar2
# lowlevel_spectral_energyband_high_dvar
# lowlevel_spectral_energyband_high_dvar2
# lowlevel_spectral_energyband_low_dvar
# lowlevel_spectral_energyband_low_dvar2
# lowlevel_spectral_energyband_middle_high_dvar
# lowlevel_spectral_energyband_middle_high_dvar2
# lowlevel_spectral_energyband_middle_low_dvar
# lowlevel_spectral_energyband_middle_low_dvar2
# lowlevel_spectral_entropy_dvar
# lowlevel_spectral_entropy_dvar2
# lowlevel_spectral_flux_dvar
# lowlevel_spectral_flux_dvar2
# lowlevel_spectral_kurtosis_dvar
# lowlevel_spectral_kurtosis_dvar2
# lowlevel_spectral_rms_dvar
# lowlevel_spectral_rms_dvar2
# lowlevel_spectral_rolloff_dvar
# lowlevel_spectral_rolloff_dvar2
# lowlevel_spectral_skewness_dvar
# lowlevel_spectral_skewness_dvar2
# lowlevel_spectral_spread_dvar
# lowlevel_spectral_spread_dvar2
# lowlevel_spectral_strongpeak_dvar
# lowlevel_spectral_strongpeak_dvar2
# lowlevel_zerocrossingrate_dvar
# lowlevel_zerocrossingrate_dvar2
# lowlevel_barkbands_dvar_0
# lowlevel_barkbands_dvar_1
# lowlevel_barkbands_dvar_2
# lowlevel_barkbands_dvar_3
# lowlevel_barkbands_dvar_4
# lowlevel_barkbands_dvar_5
# lowlevel_barkbands_dvar_6
# lowlevel_barkbands_dvar_7
# lowlevel_barkbands_dvar_8
# lowlevel_barkbands_dvar_9
# lowlevel_barkbands_dvar_10
# lowlevel_barkbands_dvar_11
# lowlevel_barkbands_dvar_12
# lowlevel_barkbands_dvar_13
# lowlevel_barkbands_dvar_14
# lowlevel_barkbands_dvar_15
# lowlevel_barkbands_dvar_16
# lowlevel_barkbands_dvar_17
# lowlevel_barkbands_dvar_18
# lowlevel_barkbands_dvar_19
# lowlevel_barkbands_dvar_20
# lowlevel_barkbands_dvar_21
# lowlevel_barkbands_dvar_22
# lowlevel_barkbands_dvar_23
# lowlevel_melbands_dvar2_19
# lowlevel_melbands_dvar2_20
# lowlevel_melbands_dvar2_21
# lowlevel_melbands_dvar2_22
# lowlevel_melbands_dvar2_23
# lowlevel_melbands_dvar2_24
# lowlevel_melbands_dvar2_25
# lowlevel_melbands_dvar2_26
# lowlevel_melbands_dvar2_27
# lowlevel_melbands_dvar2_28
# lowlevel_melbands_dvar2_29
# lowlevel_melbands_dvar2_30
# lowlevel_melbands_dvar2_31
# lowlevel_melbands_dvar2_32
# lowlevel_melbands_dvar2_33
# lowlevel_melbands_dvar2_34
# lowlevel_melbands_dvar2_35
# lowlevel_melbands_dvar2_36
# lowlevel_melbands_dvar2_37
# lowlevel_melbands_dvar2_38
# lowlevel_melbands_dvar2_39
# lowlevel_spectral_contrast_coeffs_dvar_0
# lowlevel_spectral_contrast_coeffs_dvar_1
# lowlevel_spectral_contrast_coeffs_dvar_2
# lowlevel_spectral_contrast_coeffs_dvar_3
# lowlevel_spectral_contrast_coeffs_dvar_4
# lowlevel_spectral_contrast_coeffs_dvar_5
# lowlevel_spectral_contrast_coeffs_dvar2_0
# lowlevel_spectral_contrast_coeffs_dvar2_1
# lowlevel_spectral_contrast_coeffs_dvar2_2
# lowlevel_spectral_contrast_coeffs_dvar2_3
# lowlevel_spectral_contrast_coeffs_dvar2_4
# lowlevel_spectral_contrast_coeffs_dvar2_5
# lowlevel_spectral_contrast_valleys_dvar_0
# lowlevel_spectral_contrast_valleys_dvar_1
# lowlevel_spectral_contrast_valleys_dvar_2
# lowlevel_spectral_contrast_valleys_dvar_3
# lowlevel_spectral_contrast_valleys_dvar_4
# lowlevel_spectral_contrast_valleys_dvar_5
# lowlevel_spectral_contrast_valleys_dvar2_0
# lowlevel_spectral_contrast_valleys_dvar2_1
# lowlevel_spectral_contrast_valleys_dvar2_2
# lowlevel_spectral_contrast_valleys_dvar2_3
# lowlevel_spectral_contrast_valleys_dvar2_4
# lowlevel_spectral_contrast_valleys_dvar2_5
# rhythm_beats_loudness_dvar
# rhythm_beats_loudness_dvar2
# rhythm_bpm_histogram_first_peak_bpm_dvar
# rhythm_bpm_histogram_first_peak_bpm_dvar2
# rhythm_bpm_histogram_first_peak_spread_dvar
# rhythm_bpm_histogram_first_peak_spread_dvar2
# rhythm_bpm_histogram_first_peak_weight_dvar
# rhythm_bpm_histogram_first_peak_weight_dvar2
# rhythm_bpm_histogram_second_peak_bpm_dvar
# rhythm_bpm_histogram_second_peak_bpm_dvar2
# rhythm_bpm_histogram_second_peak_spread_dvar
# rhythm_bpm_histogram_second_peak_spread_dvar2
# rhythm_bpm_histogram_second_peak_weight_dvar
# rhythm_bpm_histogram_second_peak_weight_dvar2
# rhythm_beats_loudness_band_ratio_dvar_0
# rhythm_beats_loudness_band_ratio_dvar_1
# rhythm_beats_loudness_band_ratio_dvar_2
# rhythm_beats_loudness_band_ratio_dvar_3
# rhythm_beats_loudness_band_ratio_dvar_4
# rhythm_beats_loudness_band_ratio_dvar_5
# rhythm_beats_loudness_band_ratio_dvar2_0
# rhythm_beats_loudness_band_ratio_dvar2_1
# rhythm_beats_loudness_band_ratio_dvar2_2
# rhythm_beats_loudness_band_ratio_dvar2_3
# rhythm_beats_loudness_band_ratio_dvar2_4
# rhythm_beats_loudness_band_ratio_dvar2_5
# tonal_chords_strength_dvar
# tonal_chords_strength_dvar2
# tonal_hpcp_entropy_dvar
# tonal_hpcp_entropy_dvar2
# tonal_hpcp_dvar_0
# tonal_hpcp_dvar_1
# tonal_hpcp_dvar_2
# tonal_hpcp_dvar_3
# tonal_hpcp_dvar_4
# tonal_hpcp_dvar_5
# tonal_hpcp_dvar_6
# tonal_hpcp_dvar_7
# tonal_hpcp_dvar_8
# tonal_hpcp_dvar_9
# tonal_hpcp_dvar_10
# tonal_hpcp_dvar_11
# tonal_hpcp_dvar_12
# tonal_hpcp_dvar_13
# tonal_hpcp_dvar_14
# tonal_hpcp_dvar_15
# tonal_hpcp_dvar_16
# tonal_hpcp_dvar_17
# tonal_hpcp_dvar_18
# tonal_hpcp_dvar_19
# tonal_hpcp_dvar_20
# tonal_hpcp_dvar_21
# tonal_hpcp_dvar_22
# tonal_hpcp_dvar_23
# tonal_hpcp_dvar_24
# tonal_hpcp_dvar_25
# tonal_hpcp_dvar_26
# tonal_hpcp_dvar_27
# tonal_hpcp_dvar_28
# tonal_hpcp_dvar_29
# tonal_hpcp_dvar_30
# tonal_hpcp_dvar_31
# tonal_hpcp_dvar_32
# tonal_hpcp_dvar_33
# tonal_hpcp_dvar_34
# tonal_hpcp_dvar_35
# tonal_hpcp_dvar2_0
# tonal_hpcp_dvar2_1
# tonal_hpcp_dvar2_2
# tonal_hpcp_dvar2_3
# tonal_hpcp_dvar2_4
# tonal_hpcp_dvar2_5
# tonal_hpcp_dvar2_6
# tonal_hpcp_dvar2_7
# tonal_hpcp_dvar2_8
# tonal_hpcp_dvar2_9
# tonal_hpcp_dvar2_10
# tonal_hpcp_dvar2_11
# tonal_hpcp_dvar2_12
# tonal_hpcp_dvar2_13
# tonal_hpcp_dvar2_14
# tonal_hpcp_dvar2_15
# tonal_hpcp_dvar2_16
# tonal_hpcp_dvar2_17
# tonal_hpcp_dvar2_18
# tonal_hpcp_dvar2_19
# tonal_hpcp_dvar2_20
# tonal_hpcp_dvar2_21
# tonal_hpcp_dvar2_22
# tonal_hpcp_dvar2_23
# tonal_hpcp_dvar2_24
# tonal_hpcp_dvar2_25
# tonal_hpcp_dvar2_26
# tonal_hpcp_dvar2_27
# tonal_hpcp_dvar2_28
# tonal_hpcp_dvar2_29
# tonal_hpcp_dvar2_30
# tonal_hpcp_dvar2_31
# tonal_hpcp_dvar2_32
# tonal_hpcp_dvar2_33
# tonal_hpcp_dvar2_34
# tonal_hpcp_dvar2_35
#
# 416

# %% [markdown]
# 4) min: `*.min`

# %%
counter = 0
for key in flatten_data_feats:
    if key.endswith("_min"):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# lowlevel_barkbands_crest_min
# lowlevel_barkbands_flatness_db_min
# lowlevel_barkbands_kurtosis_min
# lowlevel_barkbands_skewness_min
# lowlevel_barkbands_spread_min
# lowlevel_dissonance_min
# lowlevel_erbbands_crest_min
# lowlevel_erbbands_flatness_db_min
# lowlevel_erbbands_kurtosis_min
# lowlevel_erbbands_skewness_min
# lowlevel_erbbands_spread_min
# lowlevel_hfc_min
# lowlevel_melbands_crest_min
# lowlevel_melbands_flatness_db_min
# lowlevel_melbands_kurtosis_min
# lowlevel_melbands_skewness_min
# lowlevel_melbands_spread_min
# lowlevel_pitch_salience_min
# lowlevel_silence_rate_20dB_min
# lowlevel_silence_rate_30dB_min
# lowlevel_silence_rate_60dB_min
# lowlevel_spectral_centroid_min
# lowlevel_spectral_complexity_min
# lowlevel_spectral_decrease_min
# lowlevel_spectral_energy_min
# lowlevel_spectral_energyband_high_min
# lowlevel_spectral_energyband_low_min
# lowlevel_spectral_energyband_middle_high_min
# lowlevel_spectral_energyband_middle_low_min
# lowlevel_spectral_entropy_min
# lowlevel_spectral_flux_min
# lowlevel_spectral_kurtosis_min
# lowlevel_spectral_rms_min
# lowlevel_spectral_rolloff_min
# lowlevel_spectral_skewness_min
# lowlevel_spectral_spread_min
# lowlevel_spectral_strongpeak_min
# lowlevel_zerocrossingrate_min
# rhythm_beats_loudness_min
# rhythm_bpm_histogram_first_peak_bpm_min
# rhythm_bpm_histogram_first_peak_spread_min
# rhythm_bpm_histogram_first_peak_weight_min
# rhythm_bpm_histogram_second_peak_bpm_min
# rhythm_bpm_histogram_second_peak_spread_min
# rhythm_bpm_histogram_second_peak_weight_min
# tonal_chords_strength_min
# tonal_hpcp_entropy_min
#
# 47

# %% [markdown]
# 5) max: `*.max`

# %%
counter = 0
for key in flatten_data_feats:
    if key.endswith("_max"):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# lowlevel_barkbands_crest_max
# lowlevel_barkbands_flatness_db_max
# lowlevel_barkbands_kurtosis_max
# lowlevel_barkbands_skewness_max
# lowlevel_barkbands_spread_max
# lowlevel_dissonance_max
# lowlevel_erbbands_crest_max
# lowlevel_erbbands_flatness_db_max
# lowlevel_erbbands_kurtosis_max
# lowlevel_erbbands_skewness_max
# lowlevel_erbbands_spread_max
# lowlevel_hfc_max
# lowlevel_melbands_crest_max
# lowlevel_melbands_flatness_db_max
# lowlevel_melbands_kurtosis_max
# lowlevel_melbands_skewness_max
# lowlevel_melbands_spread_max
# lowlevel_pitch_salience_max
# lowlevel_silence_rate_20dB_max
# lowlevel_silence_rate_30dB_max
# lowlevel_silence_rate_60dB_max
# lowlevel_spectral_centroid_max
# lowlevel_spectral_complexity_max
# lowlevel_spectral_decrease_max
# lowlevel_spectral_energy_max
# lowlevel_spectral_energyband_high_max
# lowlevel_spectral_energyband_low_max
# lowlevel_spectral_energyband_middle_high_max
# lowlevel_spectral_energyband_middle_low_max
# lowlevel_spectral_entropy_max
# lowlevel_spectral_flux_max
# lowlevel_spectral_kurtosis_max
# lowlevel_spectral_rms_max
# lowlevel_spectral_rolloff_max
# lowlevel_spectral_skewness_max
# lowlevel_spectral_spread_max
# lowlevel_spectral_strongpeak_max
# lowlevel_zerocrossingrate_max
# rhythm_beats_loudness_max
# rhythm_bpm_histogram_first_peak_bpm_max
# rhythm_bpm_histogram_first_peak_spread_max
# rhythm_bpm_histogram_first_peak_weight_max
# rhythm_bpm_histogram_second_peak_bpm_max
# rhythm_bpm_histogram_second_peak_spread_max
# rhythm_bpm_histogram_second_peak_weight_max
# tonal_chords_strength_max
# tonal_hpcp_entropy_max
#
# 47

# %% [markdown]
# 6) cov: `*cov`

# %%
counter = 0
for key in flatten_data_feats:
    if re.search("cov", key):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# lowlevel_gfcc_cov_0_0
# lowlevel_gfcc_cov_0_1
# lowlevel_gfcc_cov_0_2
# lowlevel_gfcc_cov_0_3
# lowlevel_gfcc_cov_0_4
# lowlevel_gfcc_cov_0_5
# lowlevel_gfcc_cov_0_6
# lowlevel_gfcc_cov_0_7
# lowlevel_gfcc_cov_0_8
# lowlevel_gfcc_cov_0_9
# lowlevel_gfcc_cov_0_10
# lowlevel_gfcc_cov_0_11
# lowlevel_gfcc_cov_0_12
# lowlevel_gfcc_cov_1_0
# lowlevel_gfcc_cov_1_1
# lowlevel_gfcc_cov_1_2
# lowlevel_gfcc_cov_1_3
# lowlevel_gfcc_cov_1_4
# lowlevel_gfcc_cov_1_5
# lowlevel_gfcc_cov_1_6
# lowlevel_gfcc_cov_1_7
# lowlevel_gfcc_cov_1_8
# lowlevel_gfcc_cov_1_9
# lowlevel_gfcc_cov_1_10
# lowlevel_gfcc_cov_1_11
# lowlevel_gfcc_cov_1_12
# lowlevel_gfcc_cov_2_0
# lowlevel_gfcc_cov_2_1
# lowlevel_gfcc_cov_2_2
# lowlevel_gfcc_cov_2_3
# lowlevel_gfcc_cov_2_4
# lowlevel_gfcc_cov_2_5
# lowlevel_gfcc_cov_2_6
# lowlevel_gfcc_cov_2_7
# lowlevel_gfcc_cov_2_8
# lowlevel_gfcc_cov_2_9
# lowlevel_gfcc_cov_2_10
# lowlevel_gfcc_cov_2_11
# lowlevel_gfcc_cov_2_12
# lowlevel_gfcc_cov_3_0
# lowlevel_gfcc_cov_3_1
# lowlevel_gfcc_cov_3_2
# lowlevel_gfcc_cov_3_3
# lowlevel_gfcc_cov_3_4
# lowlevel_gfcc_cov_3_5
# lowlevel_gfcc_cov_3_6
# lowlevel_gfcc_cov_3_7
# lowlevel_gfcc_cov_3_8
# lowlevel_gfcc_cov_3_9
# lowlevel_gfcc_cov_3_10
# lowlevel_gfcc_cov_3_11
# lowlevel_gfcc_cov_3_12
# lowlevel_gfcc_cov_4_0
# lowlevel_gfcc_cov_4_1
# lowlevel_gfcc_cov_4_2
# lowlevel_gfcc_cov_4_3
# lowlevel_gfcc_cov_4_4
# lowlevel_gfcc_cov_4_5
# lowlevel_gfcc_cov_4_6
# lowlevel_gfcc_cov_4_7
# lowlevel_gfcc_cov_4_8
# lowlevel_gfcc_cov_4_9
# lowlevel_gfcc_icov_10_5
# lowlevel_gfcc_icov_10_6
# lowlevel_gfcc_icov_10_7
# lowlevel_gfcc_icov_10_8
# lowlevel_gfcc_icov_10_9
# lowlevel_gfcc_icov_10_10
# lowlevel_gfcc_icov_10_11
# lowlevel_gfcc_icov_10_12
# lowlevel_gfcc_icov_11_0
# lowlevel_gfcc_icov_11_1
# lowlevel_gfcc_icov_11_2
# lowlevel_gfcc_icov_11_3
# lowlevel_gfcc_icov_11_4
# lowlevel_gfcc_icov_11_5
# lowlevel_gfcc_icov_11_6
# lowlevel_gfcc_icov_11_7
# lowlevel_gfcc_icov_11_8
# lowlevel_gfcc_icov_11_9
# lowlevel_gfcc_icov_11_10
# lowlevel_gfcc_icov_11_11
# lowlevel_gfcc_icov_11_12
# lowlevel_gfcc_icov_12_0
# lowlevel_gfcc_icov_12_1
# lowlevel_gfcc_icov_12_2
# lowlevel_gfcc_icov_12_3
# lowlevel_gfcc_icov_12_4
# lowlevel_gfcc_icov_12_5
# lowlevel_gfcc_icov_12_6
# lowlevel_gfcc_icov_12_7
# lowlevel_gfcc_icov_12_8
# lowlevel_gfcc_icov_12_9
# lowlevel_gfcc_icov_12_10
# lowlevel_gfcc_icov_12_11
# lowlevel_gfcc_icov_12_12
# lowlevel_mfcc_cov_0_0
# lowlevel_mfcc_cov_0_1
# lowlevel_mfcc_cov_0_2
# lowlevel_mfcc_cov_0_3
# lowlevel_mfcc_cov_0_4
# lowlevel_mfcc_cov_0_5
# lowlevel_mfcc_cov_0_6
# lowlevel_mfcc_cov_0_7
# lowlevel_mfcc_cov_0_8
# lowlevel_mfcc_cov_0_9
# lowlevel_mfcc_cov_0_10
# lowlevel_mfcc_cov_0_11
# lowlevel_mfcc_cov_0_12
# lowlevel_mfcc_cov_1_0
# lowlevel_mfcc_cov_1_1
# lowlevel_mfcc_cov_1_2
# lowlevel_mfcc_cov_1_3
# lowlevel_mfcc_cov_1_4
# lowlevel_mfcc_cov_1_5
# lowlevel_mfcc_cov_1_6
# lowlevel_mfcc_cov_1_7
# lowlevel_mfcc_cov_1_8
# lowlevel_mfcc_cov_1_9
# lowlevel_mfcc_cov_1_10
# lowlevel_mfcc_cov_1_11
# lowlevel_mfcc_cov_1_12
# lowlevel_mfcc_cov_2_0
# lowlevel_mfcc_cov_2_1
# lowlevel_mfcc_cov_2_2
# lowlevel_mfcc_cov_2_3
# lowlevel_mfcc_cov_2_4
# lowlevel_mfcc_cov_2_5
# lowlevel_mfcc_cov_2_6
# lowlevel_mfcc_cov_2_7
# lowlevel_mfcc_cov_2_8
# lowlevel_mfcc_cov_2_9
# lowlevel_mfcc_cov_2_10
# lowlevel_mfcc_cov_2_11
# lowlevel_mfcc_cov_2_12
# lowlevel_mfcc_cov_3_0
# lowlevel_mfcc_cov_3_1
# lowlevel_mfcc_cov_3_2
# lowlevel_mfcc_cov_3_3
# lowlevel_mfcc_cov_3_4
# lowlevel_mfcc_cov_3_5
# lowlevel_mfcc_cov_3_6
# lowlevel_mfcc_cov_3_7
# lowlevel_mfcc_cov_3_8
# lowlevel_mfcc_cov_3_9
# lowlevel_mfcc_cov_3_10
# lowlevel_mfcc_cov_3_11
# lowlevel_mfcc_cov_3_12
# lowlevel_mfcc_cov_4_0
# lowlevel_mfcc_cov_4_1
# lowlevel_mfcc_cov_4_2
# lowlevel_mfcc_cov_4_3
# lowlevel_mfcc_cov_4_4
# lowlevel_mfcc_cov_4_5
# lowlevel_mfcc_cov_4_6
# lowlevel_mfcc_cov_4_7
# lowlevel_mfcc_cov_4_8
# lowlevel_mfcc_cov_4_9
# lowlevel_mfcc_cov_4_10
# lowlevel_mfcc_cov_4_11
# lowlevel_mfcc_cov_4_12
# lowlevel_mfcc_cov_5_0
# lowlevel_mfcc_cov_5_1
# lowlevel_mfcc_cov_5_2
# lowlevel_mfcc_cov_5_3
# lowlevel_mfcc_cov_5_4
# lowlevel_mfcc_cov_5_5
# lowlevel_mfcc_cov_5_6
# lowlevel_mfcc_cov_5_7
# lowlevel_mfcc_cov_5_8
# lowlevel_mfcc_cov_5_9
# lowlevel_mfcc_cov_5_10
# lowlevel_mfcc_cov_5_11
# lowlevel_mfcc_cov_5_12
# lowlevel_mfcc_cov_6_0
# lowlevel_mfcc_cov_6_1
# lowlevel_mfcc_cov_6_2
# lowlevel_mfcc_cov_6_3
# lowlevel_mfcc_cov_6_4
# lowlevel_mfcc_cov_6_5
# lowlevel_mfcc_cov_6_6
# lowlevel_mfcc_cov_6_7
# lowlevel_mfcc_cov_6_8
# lowlevel_mfcc_cov_6_9
# lowlevel_mfcc_cov_6_10
# lowlevel_mfcc_cov_6_11
# lowlevel_mfcc_cov_6_12
# lowlevel_mfcc_cov_7_0
# lowlevel_mfcc_cov_7_1
# lowlevel_mfcc_cov_7_2
# lowlevel_mfcc_cov_7_3
# lowlevel_mfcc_cov_7_4
# lowlevel_mfcc_cov_7_5
# lowlevel_mfcc_cov_7_6
# lowlevel_mfcc_cov_7_7
# lowlevel_mfcc_cov_7_8
# lowlevel_mfcc_cov_7_9
# lowlevel_mfcc_cov_7_10
# lowlevel_mfcc_cov_7_11
# lowlevel_mfcc_cov_7_12
# lowlevel_mfcc_cov_8_0
# lowlevel_mfcc_cov_8_1
# lowlevel_mfcc_cov_8_2
# lowlevel_mfcc_cov_8_3
# lowlevel_mfcc_cov_8_4
# lowlevel_mfcc_cov_8_5
# lowlevel_mfcc_cov_8_6
# lowlevel_mfcc_cov_8_7
# lowlevel_mfcc_cov_8_8
# lowlevel_mfcc_cov_8_9
# lowlevel_mfcc_cov_8_10
# lowlevel_mfcc_cov_8_11
# lowlevel_mfcc_cov_8_12
# lowlevel_mfcc_cov_9_0
# lowlevel_mfcc_cov_9_1
# lowlevel_mfcc_cov_9_2
# lowlevel_mfcc_cov_9_3
# lowlevel_mfcc_cov_9_4
# lowlevel_mfcc_cov_9_5
# lowlevel_mfcc_cov_9_6
# lowlevel_mfcc_cov_9_7
# lowlevel_mfcc_cov_9_8
# lowlevel_mfcc_cov_9_9
# lowlevel_mfcc_cov_9_10
# lowlevel_mfcc_cov_9_11
# lowlevel_mfcc_cov_9_12
# lowlevel_mfcc_cov_10_0
# lowlevel_mfcc_cov_10_1
# lowlevel_mfcc_cov_10_2
# lowlevel_mfcc_cov_10_3
# lowlevel_mfcc_cov_10_4
# lowlevel_mfcc_cov_10_5
# lowlevel_mfcc_cov_10_6
# lowlevel_mfcc_cov_10_7
# lowlevel_mfcc_cov_10_8
# lowlevel_mfcc_cov_10_9
# lowlevel_mfcc_cov_10_10
# lowlevel_mfcc_cov_10_11
# lowlevel_mfcc_cov_10_12
# lowlevel_mfcc_cov_11_0
# lowlevel_mfcc_cov_11_1
# lowlevel_mfcc_cov_11_2
# lowlevel_mfcc_cov_11_3
# lowlevel_mfcc_cov_11_4
# lowlevel_mfcc_cov_11_5
# lowlevel_mfcc_cov_11_6
# lowlevel_mfcc_cov_11_7
# lowlevel_mfcc_cov_11_8
# lowlevel_mfcc_cov_11_9
# lowlevel_mfcc_cov_11_10
# lowlevel_mfcc_cov_11_11
# lowlevel_mfcc_cov_11_12
# lowlevel_mfcc_cov_12_0
# lowlevel_mfcc_cov_12_1
# lowlevel_mfcc_cov_12_2
# lowlevel_mfcc_cov_12_3
# lowlevel_mfcc_cov_12_4
# lowlevel_mfcc_cov_12_5
# lowlevel_mfcc_cov_12_6
# lowlevel_mfcc_cov_12_7
# lowlevel_mfcc_cov_12_8
# lowlevel_mfcc_cov_12_9
# lowlevel_mfcc_cov_12_10
# lowlevel_mfcc_cov_12_11
# lowlevel_mfcc_cov_12_12
# lowlevel_mfcc_icov_0_0
# lowlevel_mfcc_icov_0_1
# lowlevel_mfcc_icov_0_2
# lowlevel_mfcc_icov_0_3
# lowlevel_mfcc_icov_0_4
# lowlevel_mfcc_icov_0_5
# lowlevel_mfcc_icov_0_6
# lowlevel_mfcc_icov_0_7
# lowlevel_mfcc_icov_0_8
# lowlevel_mfcc_icov_0_9
# lowlevel_mfcc_icov_0_10
# lowlevel_mfcc_icov_0_11
# lowlevel_mfcc_icov_0_12
# lowlevel_mfcc_icov_1_0
# lowlevel_mfcc_icov_1_1
# lowlevel_mfcc_icov_1_2
# lowlevel_mfcc_icov_1_3
# lowlevel_mfcc_icov_1_4
# lowlevel_mfcc_icov_1_5
# lowlevel_mfcc_icov_1_6
# lowlevel_mfcc_icov_1_7
# lowlevel_mfcc_icov_1_8
# lowlevel_mfcc_icov_1_9
# lowlevel_mfcc_icov_1_10
# lowlevel_mfcc_icov_1_11
# lowlevel_mfcc_icov_1_12
# lowlevel_mfcc_icov_2_0
# lowlevel_mfcc_icov_2_1
# lowlevel_mfcc_icov_2_2
# lowlevel_mfcc_icov_2_3
# lowlevel_mfcc_icov_2_4
# lowlevel_mfcc_icov_2_5
# lowlevel_mfcc_icov_2_6
# lowlevel_mfcc_icov_2_7
# lowlevel_mfcc_icov_2_8
# lowlevel_mfcc_icov_2_9
# lowlevel_mfcc_icov_2_10
# lowlevel_mfcc_icov_2_11
# lowlevel_mfcc_icov_9_1
# lowlevel_mfcc_icov_9_2
# lowlevel_mfcc_icov_9_3
# lowlevel_mfcc_icov_9_4
# lowlevel_mfcc_icov_9_5
# lowlevel_mfcc_icov_9_6
# lowlevel_mfcc_icov_9_7
# lowlevel_mfcc_icov_9_8
# lowlevel_mfcc_icov_9_9
# lowlevel_mfcc_icov_9_10
# lowlevel_mfcc_icov_9_11
# lowlevel_mfcc_icov_9_12
# lowlevel_mfcc_icov_10_0
# lowlevel_mfcc_icov_10_1
# lowlevel_mfcc_icov_10_2
# lowlevel_mfcc_icov_10_3
# lowlevel_mfcc_icov_10_4
# lowlevel_mfcc_icov_10_5
# lowlevel_mfcc_icov_10_6
# lowlevel_mfcc_icov_10_7
# lowlevel_mfcc_icov_10_8
# lowlevel_mfcc_icov_10_9
# lowlevel_mfcc_icov_10_10
# lowlevel_mfcc_icov_10_11
# lowlevel_mfcc_icov_10_12
# lowlevel_mfcc_icov_11_0
# lowlevel_mfcc_icov_11_1
# lowlevel_mfcc_icov_11_2
# lowlevel_mfcc_icov_11_3
# lowlevel_mfcc_icov_11_4
# lowlevel_mfcc_icov_11_5
# lowlevel_mfcc_icov_11_6
# lowlevel_mfcc_icov_11_7
# lowlevel_mfcc_icov_11_8
# lowlevel_mfcc_icov_11_9
# lowlevel_mfcc_icov_11_10
# lowlevel_mfcc_icov_11_11
# lowlevel_mfcc_icov_11_12
# lowlevel_mfcc_icov_12_0
# lowlevel_mfcc_icov_12_1
# lowlevel_mfcc_icov_12_2
# lowlevel_mfcc_icov_12_3
# lowlevel_mfcc_icov_12_4
# lowlevel_mfcc_icov_12_5
# lowlevel_mfcc_icov_12_6
# lowlevel_mfcc_icov_12_7
# lowlevel_mfcc_icov_12_8
# lowlevel_mfcc_icov_12_9
# lowlevel_mfcc_icov_12_10
# lowlevel_mfcc_icov_12_11
# lowlevel_mfcc_icov_12_12
#
# 676

# %% [markdown]
# 7) tonal.thpcp: `tonal.thpcp`

# %%
counter = 0
for key in flatten_data_feats:
    if re.search("tonal_thpcp", key):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# tonal_thpcp_0
# tonal_thpcp_1
# tonal_thpcp_2
# tonal_thpcp_3
# tonal_thpcp_4
# tonal_thpcp_5
# tonal_thpcp_6
# tonal_thpcp_7
# tonal_thpcp_8
# tonal_thpcp_9
# tonal_thpcp_10
# tonal_thpcp_11
# tonal_thpcp_12
# tonal_thpcp_13
# tonal_thpcp_14
# tonal_thpcp_15
# tonal_thpcp_16
# tonal_thpcp_17
# tonal_thpcp_18
# tonal_thpcp_19
# tonal_thpcp_20
# tonal_thpcp_21
# tonal_thpcp_22
# tonal_thpcp_23
# tonal_thpcp_24
# tonal_thpcp_25
# tonal_thpcp_26
# tonal_thpcp_27
# tonal_thpcp_28
# tonal_thpcp_29
# tonal_thpcp_30
# tonal_thpcp_31
# tonal_thpcp_32
# tonal_thpcp_33
# tonal_thpcp_34
# tonal_thpcp_35
#
# 36

# %% [markdown]
# 8) lowlevel.spectral_energyband_high: `lowlevel.spectral_energyband_high.*`

# %%
counter = 0
for key in flatten_data_feats:
    if re.search("lowlevel_spectral_energyband_high", key):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# lowlevel_spectral_energyband_high_dmean
# lowlevel_spectral_energyband_high_dmean2
# lowlevel_spectral_energyband_high_dvar
# lowlevel_spectral_energyband_high_dvar2
# lowlevel_spectral_energyband_high_max
# lowlevel_spectral_energyband_high_mean
# lowlevel_spectral_energyband_high_median
# lowlevel_spectral_energyband_high_min
# lowlevel_spectral_energyband_high_var
#
# 9

# %% [markdown]
# 9) lowlevel.silence_rate: `lowlevel.silence_rate*`

# %%
counter = 0
for key in flatten_data_feats:
    if re.search("lowlevel_silence_rate", key):
        print(key)
        counter += 1
print()
print(counter)
# Out:
# lowlevel_silence_rate_20dB_dmean
# lowlevel_silence_rate_20dB_dmean2
# lowlevel_silence_rate_20dB_dvar
# lowlevel_silence_rate_20dB_dvar2
# lowlevel_silence_rate_20dB_max
# lowlevel_silence_rate_20dB_mean
# lowlevel_silence_rate_20dB_median
# lowlevel_silence_rate_20dB_min
# lowlevel_silence_rate_20dB_var
# lowlevel_silence_rate_30dB_dmean
# lowlevel_silence_rate_30dB_dmean2
# lowlevel_silence_rate_30dB_dvar
# lowlevel_silence_rate_30dB_dvar2
# lowlevel_silence_rate_30dB_max
# lowlevel_silence_rate_30dB_mean
# lowlevel_silence_rate_30dB_median
# lowlevel_silence_rate_30dB_min
# lowlevel_silence_rate_30dB_var
# lowlevel_silence_rate_60dB_dmean
# lowlevel_silence_rate_60dB_dmean2
# lowlevel_silence_rate_60dB_dvar
# lowlevel_silence_rate_60dB_dvar2
# lowlevel_silence_rate_60dB_max
# lowlevel_silence_rate_60dB_mean
# lowlevel_silence_rate_60dB_median
# lowlevel_silence_rate_60dB_min
# lowlevel_silence_rate_60dB_var
#
# 27

# %%
for key, value in flatten_data_feats.items():
    
    if re.search("mfcc", key):
        print(key)
# Out:
# lowlevel_mfcc_mean_0
# lowlevel_mfcc_mean_1
# lowlevel_mfcc_mean_2
# lowlevel_mfcc_mean_3
# lowlevel_mfcc_mean_4
# lowlevel_mfcc_mean_5
# lowlevel_mfcc_mean_6
# lowlevel_mfcc_mean_7
# lowlevel_mfcc_mean_8
# lowlevel_mfcc_mean_9
# lowlevel_mfcc_mean_10
# lowlevel_mfcc_mean_11
# lowlevel_mfcc_mean_12
# lowlevel_mfcc_cov_0_0
# lowlevel_mfcc_cov_0_1
# lowlevel_mfcc_cov_0_2
# lowlevel_mfcc_cov_0_3
# lowlevel_mfcc_cov_0_4
# lowlevel_mfcc_cov_0_5
# lowlevel_mfcc_cov_0_6
# lowlevel_mfcc_cov_0_7
# lowlevel_mfcc_cov_0_8
# lowlevel_mfcc_cov_0_9
# lowlevel_mfcc_cov_0_10
# lowlevel_mfcc_cov_0_11
# lowlevel_mfcc_cov_0_12
# lowlevel_mfcc_cov_1_0
# lowlevel_mfcc_cov_1_1
# lowlevel_mfcc_cov_1_2
# lowlevel_mfcc_cov_1_3
# lowlevel_mfcc_cov_1_4
# lowlevel_mfcc_cov_1_5
# lowlevel_mfcc_cov_1_6
# lowlevel_mfcc_cov_1_7
# lowlevel_mfcc_cov_1_8
# lowlevel_mfcc_cov_1_9
# lowlevel_mfcc_cov_1_10
# lowlevel_mfcc_cov_1_11
# lowlevel_mfcc_cov_1_12
# lowlevel_mfcc_cov_2_0
# lowlevel_mfcc_cov_2_1
# lowlevel_mfcc_cov_2_2
# lowlevel_mfcc_cov_2_3
# lowlevel_mfcc_cov_2_4
# lowlevel_mfcc_cov_2_5
# lowlevel_mfcc_cov_2_6
# lowlevel_mfcc_cov_2_7
# lowlevel_mfcc_cov_2_8
# lowlevel_mfcc_cov_2_9
# lowlevel_mfcc_cov_2_10
# lowlevel_mfcc_cov_2_11
# lowlevel_mfcc_cov_2_12
# lowlevel_mfcc_cov_3_0
# lowlevel_mfcc_cov_3_1
# lowlevel_mfcc_cov_3_2
# lowlevel_mfcc_cov_3_3
# lowlevel_mfcc_cov_3_4
# lowlevel_mfcc_cov_3_5
# lowlevel_mfcc_cov_3_6
# lowlevel_mfcc_cov_3_7
# lowlevel_mfcc_cov_3_8
# lowlevel_mfcc_cov_3_9
# lowlevel_mfcc_cov_3_10
# lowlevel_mfcc_cov_3_11
# lowlevel_mfcc_cov_3_12
# lowlevel_mfcc_cov_4_0
# lowlevel_mfcc_cov_4_1
# lowlevel_mfcc_cov_4_2
# lowlevel_mfcc_cov_4_3
# lowlevel_mfcc_cov_4_4
# lowlevel_mfcc_cov_4_5
# lowlevel_mfcc_cov_4_6
# lowlevel_mfcc_cov_4_7
# lowlevel_mfcc_cov_4_8
# lowlevel_mfcc_cov_4_9
# lowlevel_mfcc_cov_4_10
# lowlevel_mfcc_cov_4_11
# lowlevel_mfcc_cov_4_12
# lowlevel_mfcc_cov_5_0
# lowlevel_mfcc_cov_5_1
# lowlevel_mfcc_cov_5_2
# lowlevel_mfcc_cov_5_3
# lowlevel_mfcc_cov_5_4
# lowlevel_mfcc_cov_5_5
# lowlevel_mfcc_cov_5_6
# lowlevel_mfcc_cov_5_7
# lowlevel_mfcc_cov_5_8
# lowlevel_mfcc_cov_5_9
# lowlevel_mfcc_cov_5_10
# lowlevel_mfcc_cov_5_11
# lowlevel_mfcc_cov_5_12
# lowlevel_mfcc_cov_6_0
# lowlevel_mfcc_cov_6_1
# lowlevel_mfcc_cov_6_2
# lowlevel_mfcc_cov_6_3
# lowlevel_mfcc_cov_6_4
# lowlevel_mfcc_cov_6_5
# lowlevel_mfcc_cov_6_6
# lowlevel_mfcc_cov_6_7
# lowlevel_mfcc_cov_6_8
# lowlevel_mfcc_cov_6_9
# lowlevel_mfcc_cov_6_10
# lowlevel_mfcc_cov_6_11
# lowlevel_mfcc_cov_6_12
# lowlevel_mfcc_cov_7_0
# lowlevel_mfcc_cov_7_1
# lowlevel_mfcc_cov_7_2
# lowlevel_mfcc_cov_7_3
# lowlevel_mfcc_cov_7_4
# lowlevel_mfcc_cov_7_5
# lowlevel_mfcc_cov_7_6
# lowlevel_mfcc_cov_7_7
# lowlevel_mfcc_cov_7_8
# lowlevel_mfcc_cov_7_9
# lowlevel_mfcc_cov_7_10
# lowlevel_mfcc_cov_7_11
# lowlevel_mfcc_cov_7_12
# lowlevel_mfcc_cov_8_0
# lowlevel_mfcc_cov_8_1
# lowlevel_mfcc_cov_8_2
# lowlevel_mfcc_cov_8_3
# lowlevel_mfcc_cov_8_4
# lowlevel_mfcc_cov_8_5
# lowlevel_mfcc_cov_8_6
# lowlevel_mfcc_cov_8_7
# lowlevel_mfcc_cov_8_8
# lowlevel_mfcc_cov_8_9
# lowlevel_mfcc_cov_8_10
# lowlevel_mfcc_cov_8_11
# lowlevel_mfcc_cov_8_12
# lowlevel_mfcc_cov_9_0
# lowlevel_mfcc_cov_9_1
# lowlevel_mfcc_cov_9_2
# lowlevel_mfcc_cov_9_3
# lowlevel_mfcc_cov_9_4
# lowlevel_mfcc_cov_9_5
# lowlevel_mfcc_cov_9_6
# lowlevel_mfcc_cov_9_7
# lowlevel_mfcc_cov_9_8
# lowlevel_mfcc_cov_9_9
# lowlevel_mfcc_cov_9_10
# lowlevel_mfcc_cov_9_11
# lowlevel_mfcc_cov_9_12
# lowlevel_mfcc_cov_10_0
# lowlevel_mfcc_cov_10_1
# lowlevel_mfcc_cov_10_2
# lowlevel_mfcc_cov_10_3
# lowlevel_mfcc_cov_10_4
# lowlevel_mfcc_cov_10_5
# lowlevel_mfcc_cov_10_6
# lowlevel_mfcc_cov_10_7
# lowlevel_mfcc_cov_10_8
# lowlevel_mfcc_cov_10_9
# lowlevel_mfcc_cov_10_10
# lowlevel_mfcc_cov_10_11
# lowlevel_mfcc_cov_10_12
# lowlevel_mfcc_cov_11_0
# lowlevel_mfcc_cov_11_1
# lowlevel_mfcc_cov_11_2
# lowlevel_mfcc_cov_11_3
# lowlevel_mfcc_cov_11_4
# lowlevel_mfcc_cov_11_5
# lowlevel_mfcc_cov_11_6
# lowlevel_mfcc_cov_11_7
# lowlevel_mfcc_cov_11_8
# lowlevel_mfcc_cov_11_9
# lowlevel_mfcc_cov_11_10
# lowlevel_mfcc_cov_11_11
# lowlevel_mfcc_cov_11_12
# lowlevel_mfcc_cov_12_0
# lowlevel_mfcc_cov_12_1
# lowlevel_mfcc_cov_12_2
# lowlevel_mfcc_cov_12_3
# lowlevel_mfcc_cov_12_4
# lowlevel_mfcc_cov_12_5
# lowlevel_mfcc_cov_12_6
# lowlevel_mfcc_cov_12_7
# lowlevel_mfcc_cov_12_8
# lowlevel_mfcc_cov_12_9
# lowlevel_mfcc_cov_12_10
# lowlevel_mfcc_cov_12_11
# lowlevel_mfcc_cov_12_12
# lowlevel_mfcc_icov_0_0
# lowlevel_mfcc_icov_0_1
# lowlevel_mfcc_icov_0_2
# lowlevel_mfcc_icov_0_3
# lowlevel_mfcc_icov_0_4
# lowlevel_mfcc_icov_0_5
# lowlevel_mfcc_icov_0_6
# lowlevel_mfcc_icov_0_7
# lowlevel_mfcc_icov_0_8
# lowlevel_mfcc_icov_0_9
# lowlevel_mfcc_icov_0_10
# lowlevel_mfcc_icov_0_11
# lowlevel_mfcc_icov_0_12
# lowlevel_mfcc_icov_1_0
# lowlevel_mfcc_icov_1_1
# lowlevel_mfcc_icov_1_2
# lowlevel_mfcc_icov_1_3
# lowlevel_mfcc_icov_1_4
# lowlevel_mfcc_icov_1_5
# lowlevel_mfcc_icov_1_6
# lowlevel_mfcc_icov_1_7
# lowlevel_mfcc_icov_1_8
# lowlevel_mfcc_icov_1_9
# lowlevel_mfcc_icov_1_10
# lowlevel_mfcc_icov_1_11
# lowlevel_mfcc_icov_1_12
# lowlevel_mfcc_icov_2_0
# lowlevel_mfcc_icov_2_1
# lowlevel_mfcc_icov_2_2
# lowlevel_mfcc_icov_2_3
# lowlevel_mfcc_icov_2_4
# lowlevel_mfcc_icov_2_5
# lowlevel_mfcc_icov_2_6
# lowlevel_mfcc_icov_2_7
# lowlevel_mfcc_icov_2_8
# lowlevel_mfcc_icov_2_9
# lowlevel_mfcc_icov_2_10
# lowlevel_mfcc_icov_2_11
# lowlevel_mfcc_icov_2_12
# lowlevel_mfcc_icov_3_0
# lowlevel_mfcc_icov_3_1
# lowlevel_mfcc_icov_3_2
# lowlevel_mfcc_icov_3_3
# lowlevel_mfcc_icov_3_4
# lowlevel_mfcc_icov_3_5
# lowlevel_mfcc_icov_3_6
# lowlevel_mfcc_icov_3_7
# lowlevel_mfcc_icov_3_8
# lowlevel_mfcc_icov_3_9
# lowlevel_mfcc_icov_3_10
# lowlevel_mfcc_icov_3_11
# lowlevel_mfcc_icov_3_12
# lowlevel_mfcc_icov_4_0
# lowlevel_mfcc_icov_4_1
# lowlevel_mfcc_icov_4_2
# lowlevel_mfcc_icov_4_3
# lowlevel_mfcc_icov_4_4
# lowlevel_mfcc_icov_4_5
# lowlevel_mfcc_icov_4_6
# lowlevel_mfcc_icov_4_7
# lowlevel_mfcc_icov_4_8
# lowlevel_mfcc_icov_4_9
# lowlevel_mfcc_icov_4_10
# lowlevel_mfcc_icov_4_11
# lowlevel_mfcc_icov_4_12
# lowlevel_mfcc_icov_5_0
# lowlevel_mfcc_icov_5_1
# lowlevel_mfcc_icov_5_2
# lowlevel_mfcc_icov_5_3
# lowlevel_mfcc_icov_5_4
# lowlevel_mfcc_icov_5_5
# lowlevel_mfcc_icov_5_6
# lowlevel_mfcc_icov_5_7
# lowlevel_mfcc_icov_5_8
# lowlevel_mfcc_icov_5_9
# lowlevel_mfcc_icov_5_10
# lowlevel_mfcc_icov_5_11
# lowlevel_mfcc_icov_5_12
# lowlevel_mfcc_icov_6_0
# lowlevel_mfcc_icov_6_1
# lowlevel_mfcc_icov_6_2
# lowlevel_mfcc_icov_6_3
# lowlevel_mfcc_icov_6_4
# lowlevel_mfcc_icov_6_5
# lowlevel_mfcc_icov_6_6
# lowlevel_mfcc_icov_6_7
# lowlevel_mfcc_icov_6_8
# lowlevel_mfcc_icov_6_9
# lowlevel_mfcc_icov_6_10
